# %% [markdown]
# # Data Mining 1
# ## Neuronale Netze - Beispielprogramm
# ### Implementierung der logistischen Regression als neuronales Netz

# %% [markdown]
# ### 1 - Preparations
# #### 1.1 - Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import sklearn.datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import accuracy_score
import pandas as pd

# Display plots inline and change default figure size
import matplotlib
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)

# %% [markdown]
# #### 1.2 - Generating a dataset

# %%
# Generate a dataset and plot it
n          = 1000
data_seed  = 1337
split_seed = 42
test_size  = 0.25

np.random.seed(data_seed)
X, y = sklearn.datasets.make_moons(n, noise=0.25)
plt.scatter(X[:,0], X[:,1], s=40, c=y, cmap=plt.cm.Spectral);

# %% [markdown]
# #### 1.3 - Split the dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=test_size, 
                                                    random_state=split_seed)

# %% [markdown]
# ##### Training Data:

# %%
plt.scatter(X_train[:,0], X_train[:,1], s=40, c=y_train, cmap=plt.cm.Spectral);

# %% [markdown]
# ##### Validation Data:

# %%
plt.scatter(X_test[:,0], X_test[:,1], s=40, c=y_test, cmap=plt.cm.Spectral);

# %% [markdown]
# ### 2- Implementierung
# #### 2.1 - Aktivierungsfunktion (activation function)
# Als Aktivierungsfunktion des Output-Layers wird die logistische Funktion
#
# $\displaystyle \sigma\colon \,\mathbb{R}\to \left(0,1\right), \;z \mapsto\frac{1}{1+\exp(-z)}$
#
# verwendet.

# %%
def sigmoid(z):
    return 1/(1+np.exp(-z))

# %% [markdown]
# #### 2.2 Kostenfunktion (cost function)
# Als Kostenfunktion wird folgende quadratische Fehlerfunktion verwendet:
#
# $\displaystyle E(y,\widehat{\pi}) = \frac{1}{2}\sum_{k=1}^{n}\left(y_k-\widehat{\pi_k}\right)^2$
#
# wobei $y=\left(y_1,\dots,y_n\right)^T$ und $\widehat{\pi}=\left(\widehat{\pi_1},\dots,\widehat{\pi_n}\right)^T$.

# %%
def calculate_loss(model,X,y):
    # Extraktion der Modellparameter
    W1, b1 = model['W1'], model['b1']
    
    # Berechnung der geschätzten Klassenwahrscheinlichkeiten (Forward Propagation)
    z1 = X.dot(W1) + b1
    probs = sigmoid(z1)[:,0]
    
    # Berechnung des Kostenfunktionswertes
    cost = np.power(y-probs,2)
    cost = np.sum(cost)/2
    
    return cost

# %% [markdown]
# #### 2.3 - Hilfsfunktion für Vorhersagen
# - **model:** Ein Modell aus Abschnitt 2.4
# - **x:** Neue Daten
# - **proba:**
#     - *True:* Geschätzte Wahrscheinlichkeiten werden zurückgegeben
#     - *False:* Geschätzte Klassen werden zurückgegeben
# - **cutpoint:** Schnittpunkt entscheidet welche Klasse prognostiziert wird

# %%
def predict(model, x,proba = False,cutpoint = 0.5):
    
    # Extraktion der Modellparameter
    W1, b1 = model['W1'], model['b1']

    # Berechnung der geschätzten Klassenwahrscheinlichkeiten (Forward Propagation)
    z1 = x.dot(W1) + b1
    probs = sigmoid(z1)
    
    if(proba):
        return probs
    return (probs>cutpoint)*1

# %% [markdown]
# #### 2.4 - Implementierung des Modells

# %%
def build_model(X,                              # Features
                y,                              # Target
                iterations            = 20000,  # Number of gradient descent iterations
                print_loss            = False,  # Print cost function during model adjustment
                print_loss_after_iter = 100,    # Number of iterations after cost function is to be printed
                learing_rate          = 0.1,    # Learning rate of Gradient descent
                random_state          = None):  # Random seed of weights 

    observations = X.shape[0] # Number of observations
    features     = X.shape[1] # Number of features

    # Initialize the parameters to random values:
    rand_range = 0.05
    np.random.seed(random_state)
    W1 = np.random.uniform(low = -rand_range, 
                           high = rand_range, 
                           size= (features,1))
    b1 = np.zeros((1,1))
    
    # This is what we return at the end
    model = {}

    # Gradient descent:
    for i in range(0, iterations):

        # Forward propagation
        z1 = X.dot(W1) + b1
        probs = sigmoid(z1)

        # Backpropagation       
        delta = (probs-y.reshape((observations,1))) * probs * (1 - probs)
        dW1 = np.dot(X.T, delta)
        db1 = np.sum(delta, axis=0)

        # Gradient descent parameter update
        W1 += -learing_rate * dW1
        b1 += -learing_rate * db1
        
        # Assign new parameters to the model
        model = { 'W1': W1, 'b1': b1}
        
        # Optionally print the loss.
        # This is expensive because it uses the whole dataset, so we don't want to do it too often.
        if print_loss and i % print_loss_after_iter == 0:
            print("Loss after iteration %7d:\t%f" %(i, calculate_loss(model,X,y)))
    return model

# %% [markdown]
# #### 2.6 Anpassung des Modells

# %%
model = build_model(X            = X_train,
                    y            = y_train, 
                    iterations   = 1000,
                    print_loss   = True,
                    random_state = 42)
# Out:
# Loss after iteration       0:	55.524902
# Loss after iteration     100:	34.838308
# Loss after iteration     200:	34.838308
# Loss after iteration     300:	34.838308
# Loss after iteration     400:	34.838308
# Loss after iteration     500:	34.838308
# Loss after iteration     600:	34.838308
# Loss after iteration     700:	34.838308
# Loss after iteration     800:	34.838308
# Loss after iteration     900:	34.838308

# %% [markdown]
# ### 3 - Auswertung der Ergebnisse
# #### 3.1 - Grafische Veranschaulichung des Modells

# %%
# Helper function to plot a decision boundary.
def plot_decision_boundary(pred_func,X,y):
    # Set min and max values and give it some padding
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    h = 0.01
    
    # Generate a grid of points with distance h between them
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    
    # Predict the function value for the whole gid
    Z = pred_func(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    
    # Plot the contour and training examples
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Spectral)

# %% [markdown]
# ##### 3.1.1 - Gesamter Datensatz

# %%
plot_decision_boundary(lambda x: predict(model, x),X,y);

# %% [markdown]
# ##### 3.1.2 - Trainingsdaten

# %%
plot_decision_boundary(lambda x: predict(model, x),X_train,y_train);

# %% [markdown]
# ##### 3.1.3 - Validierungsdaten

# %%
plot_decision_boundary(lambda x: predict(model, x),X_test,y_test);

# %% [markdown]
# #### 3.2 ROC curve

# %%
# calculate the fpr and tpr for all thresholds of the classification
# Training Data
probs_train = predict(model,X_train,proba=True)
fpr_train, tpr_train, _ = roc_curve(y_train, probs_train)
auc_train = auc(fpr_train, tpr_train)

# Validation Data
probs_test = predict(model,X_test,proba=True)
fpr_test, tpr_test, _ = roc_curve(y_test, probs_test)
auc_test = auc(fpr_test, tpr_test)

# %%
# Plot ROC curves + AUC values
plt.title('Receiver Operating Characteristic')
plt.plot(fpr_train, tpr_train, 'b', label = 'Train  (AUC = %0.4f)' % auc_train)
plt.plot(fpr_test,  tpr_test,  'g', label = 'Test   (AUC = %0.4f)' % auc_test)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# %% [markdown]
# #### 3.3 Confusion Matrix
# ##### 3.3.1 Trainingsdaten

# %%
y_actu_train = pd.Series(y_train, name='Actual')
y_pred_train = pd.Series(predict(model,X_train)[:,0], name='Predicted')
df_conf_train = pd.crosstab(y_actu_train, y_pred_train)
print(df_conf_train)
# Out:
# Predicted    0    1
# Actual
# 0          328   48
# 1           46  328

# %% [markdown]
# ##### 3.3.1 Validierungsdaten

# %%
y_actu_test = pd.Series(y_test, name='Actual')
y_pred_test = pd.Series(predict(model,X_test)[:,0], name='Predicted')
df_conf_test = pd.crosstab(y_actu_test, y_pred_test)
print(df_conf_test)
# Out:
# Predicted    0    1
# Actual
# 0          105   19
# 1           22  104

# %% [markdown]
# #### 3.4 Metriken

# %%
acc_train = accuracy_score(y_actu_train,y_pred_train)
acc_test  = accuracy_score(y_actu_test, y_pred_test)
print("-- Accuracy --")
print("Train:\t{:2.2f}%".format(acc_train*100))
print("Test:\t{:2.2f}%".format(acc_test*100))
print("\n-- Misclassification Rate --")
print("Train:\t{:2.2f}%".format((1-acc_train)*100))
print("Test:\t{:2.2f}%".format((1-acc_test)*100))
# Out:
# -- Accuracy --
# Train:	87.47%
# Test:	83.60%
#
# -- Misclassification Rate --
# Train:	12.53%
# Test:	16.40%

# %% [markdown]
# ## 4 Deep Learning Library Keras
# #### 4.1 Aufbau und Training des Modells
# Mithilfe von Keras können einzelne Layer sequentiell dem Modell hinzugefügt werden. Siehe [Getting started with the Keras Sequential model](https://keras.io/getting-started/sequential-model-guide/) und [The Sequential model API](https://keras.io/models/sequential/)
# Unter anderem sind dabei folgende Punkte zu beachten:
# * Beim ersten Layer muss mit **input_dim**, die Anzahl der Features (abhängigen Merkmalsvariablen) angegeben werden
# * Beim letzten Layer muss die Anzahl der Neuronen mit der Anzahl der Targets übereinstimmen
#
# Alle nötigen Informationen zum Umgang mit Keras können Sie auf der offiziellen Seite von Keras finden:
# **[Keras: The Python Deep Learning library](https://keras.io)**

# %%
#Imports
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.regularizers import l2
from keras.initializers import RandomUniform,Constant

#START A NEW TF SESSION - Für Reproduzierbarkeit notwendig
import tensorflow as tf
from keras import backend as K
np.random.seed(42)
tf.set_random_seed(1337)
sess = tf.Session(graph=tf.get_default_graph())
K.set_session(sess)

# %% [markdown]
# ##### 4.1.1  Aufbau des Modells
# Zunächst muss mit $\texttt{Sequential}$ ein Modell-Objekt erzeugt werden. Anschließend können mit der Methode $\texttt{add}$ Layer hinzugefügt werden.
# - Mögliche Einstellungen der einfachen Layer: [Core Layers](https://keras.io/layers/core/)
# - [Usage of activations](https://keras.io/activations/)
# - [Usage of regularizers](https://keras.io/regularizers/)

# %%
# Build model
keras_model = Sequential()

# Add Layers
keras_model.add(Dense(1,
                activation='sigmoid',
                input_dim=2))

# %% [markdown]
# ##### 4.1.2  Optionen für die Modellanpassung
# Anschließend müssen mit der compile-Methode verschiedene Einstellungen für die Modellanpassung getroffen werden.
# - **optimizer:** Optimierungsalgorithmus ([Usage of optimizers](https://keras.io/optimizers/))
# - **loss:** Auswahl der gewünschten Zielfunktion nach der das Modell optimiert werden soll ([Usage of loss functions](https://keras.io/losses/))
# - **metrics:** Metriken die werden der Modellanpassung berechnet werden sollen
# - Weitere Parameter sind unter [The Sequential model API
# ](https://keras.io/models/sequential/) zu finden

# %%
# Training Options
keras_model.compile(optimizer='rmsprop',
                    loss='binary_crossentropy',
                    metrics=['accuracy'])

# %%
# Übersicht des Modells
print(keras_model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1)                 3
# =================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ##### 4.1.3 Anpassung des Modells
# Durch die Methode $\texttt{fit}$ kann das Modell schließlich trainiert werden. Siehe hierzu wieder:
# [The Sequential model API](https://keras.io/models/sequential/)

# %%
# Fitting of the model
model_history = keras_model.fit(X_train,
                                y_train, 
                                epochs          = 250,
                                validation_data = (X_test, y_test),
                                verbose         = 2,
                                batch_size      = 32)
# Out:
# Train on 750 samples, validate on 250 samples
# Epoch 1/250
#  - 0s - loss: 0.7786 - acc: 0.5747 - val_loss: 0.7921 - val_acc: 0.5840
# Epoch 2/250
#  - 0s - loss: 0.7679 - acc: 0.5760 - val_loss: 0.7836 - val_acc: 0.5720
# Epoch 3/250
#  - 0s - loss: 0.7584 - acc: 0.5813 - val_loss: 0.7751 - val_acc: 0.5760
# Epoch 4/250
#  - 0s - loss: 0.7489 - acc: 0.5840 - val_loss: 0.7666 - val_acc: 0.5680
# Epoch 5/250
#  - 0s - loss: 0.7396 - acc: 0.5840 - val_loss: 0.7583 - val_acc: 0.5760
# Epoch 6/250
#  - 0s - loss: 0.7304 - acc: 0.5893 - val_loss: 0.7505 - val_acc: 0.5680
# Epoch 7/250
#  - 0s - loss: 0.7216 - acc: 0.5933 - val_loss: 0.7428 - val_acc: 0.5640
# Epoch 8/250
#  - 0s - loss: 0.7129 - acc: 0.5893 - val_loss: 0.7353 - val_acc: 0.5680
# Epoch 9/250
#  - 0s - loss: 0.7046 - acc: 0.5973 - val_loss: 0.7280 - val_acc: 0.5680
# Epoch 10/250
#  - 0s - loss: 0.6962 - acc: 0.5987 - val_loss: 0.7207 - val_acc: 0.5640
# Epoch 11/250
#  - 0s - loss: 0.6880 - acc: 0.6000 - val_loss: 0.7133 - val_acc: 0.5720
# Epoch 12/250
#  - 0s - loss: 0.6799 - acc: 0.6067 - val_loss: 0.7062 - val_acc: 0.5640
# Epoch 13/250
#  - 0s - loss: 0.6723 - acc: 0.6067 - val_loss: 0.6996 - val_acc: 0.5640
# Epoch 14/250
#  - 0s - loss: 0.6649 - acc: 0.6067 - val_loss: 0.6930 - val_acc: 0.5680
# Epoch 15/250
#  - 0s - loss: 0.6577 - acc: 0.6093 - val_loss: 0.6868 - val_acc: 0.5680
# Epoch 16/250
#  - 0s - loss: 0.6507 - acc: 0.6133 - val_loss: 0.6805 - val_acc: 0.5680
# Epoch 17/250
#  - 0s - loss: 0.6436 - acc: 0.6160 - val_loss: 0.6740 - val_acc: 0.5760
# Epoch 18/250
#  - 0s - loss: 0.6366 - acc: 0.6187 - val_loss: 0.6680 - val_acc: 0.5800
# Epoch 19/250
#  - 0s - loss: 0.6298 - acc: 0.6173 - val_loss: 0.6620 - val_acc: 0.5840
# Epoch 20/250
#  - 0s - loss: 0.6230 - acc: 0.6240 - val_loss: 0.6561 - val_acc: 0.5840
# Epoch 21/250
#  - 0s - loss: 0.6168 - acc: 0.6293 - val_loss: 0.6509 - val_acc: 0.5800
# Epoch 22/250
#  - 0s - loss: 0.6108 - acc: 0.6373 - val_loss: 0.6455 - val_acc: 0.5760
# Epoch 23/250
#  - 0s - loss: 0.6047 - acc: 0.6387 - val_loss: 0.6404 - val_acc: 0.5720
# Epoch 24/250
#  - 0s - loss: 0.5988 - acc: 0.6400 - val_loss: 0.6352 - val_acc: 0.5800
# Epoch 25/250
#  - 0s - loss: 0.5933 - acc: 0.6427 - val_loss: 0.6305 - val_acc: 0.5920
# Epoch 26/250
#  - 0s - loss: 0.5877 - acc: 0.6480 - val_loss: 0.6257 - val_acc: 0.5960
# Epoch 27/250
#  - 0s - loss: 0.5824 - acc: 0.6480 - val_loss: 0.6214 - val_acc: 0.5960
# Epoch 28/250
#  - 0s - loss: 0.5772 - acc: 0.6507 - val_loss: 0.6167 - val_acc: 0.6000
# Epoch 29/250
#  - 0s - loss: 0.5721 - acc: 0.6547 - val_loss: 0.6121 - val_acc: 0.6040
# Epoch 30/250
#  - 0s - loss: 0.5670 - acc: 0.6560 - val_loss: 0.6079 - val_acc: 0.6040
# Epoch 31/250
#  - 0s - loss: 0.5623 - acc: 0.6600 - val_loss: 0.6037 - val_acc: 0.6000
# Epoch 32/250
#  - 0s - loss: 0.5575 - acc: 0.6640 - val_loss: 0.5996 - val_acc: 0.6080
# Epoch 33/250
#  - 0s - loss: 0.5530 - acc: 0.6627 - val_loss: 0.5959 - val_acc: 0.6040
# Epoch 34/250
#  - 0s - loss: 0.5485 - acc: 0.6680 - val_loss: 0.5919 - val_acc: 0.6040
# Epoch 35/250
#  - 0s - loss: 0.5442 - acc: 0.6693 - val_loss: 0.5884 - val_acc: 0.6000
# Epoch 36/250
#  - 0s - loss: 0.5400 - acc: 0.6733 - val_loss: 0.5847 - val_acc: 0.6080
# Epoch 37/250
#  - 0s - loss: 0.5358 - acc: 0.6747 - val_loss: 0.5811 - val_acc: 0.6040
# Epoch 38/250
#  - 0s - loss: 0.5316 - acc: 0.6787 - val_loss: 0.5776 - val_acc: 0.6080
# Epoch 39/250
#  - 0s - loss: 0.5276 - acc: 0.6787 - val_loss: 0.5743 - val_acc: 0.6040
# Epoch 40/250
#  - 0s - loss: 0.5237 - acc: 0.6827 - val_loss: 0.5710 - val_acc: 0.6040
# Epoch 41/250
#  - 0s - loss: 0.5200 - acc: 0.6853 - val_loss: 0.5677 - val_acc: 0.6000
# Epoch 42/250
#  - 0s - loss: 0.5162 - acc: 0.6867 - val_loss: 0.5647 - val_acc: 0.6040
# Epoch 43/250
#  - 0s - loss: 0.5126 - acc: 0.6893 - val_loss: 0.5616 - val_acc: 0.6120
# Epoch 44/250
#  - 0s - loss: 0.5091 - acc: 0.6947 - val_loss: 0.5587 - val_acc: 0.6160
# Epoch 45/250
#  - 0s - loss: 0.5056 - acc: 0.6947 - val_loss: 0.5557 - val_acc: 0.6160
# Epoch 46/250
#  - 0s - loss: 0.5021 - acc: 0.6973 - val_loss: 0.5527 - val_acc: 0.6160
# Epoch 47/250
#  - 0s - loss: 0.4987 - acc: 0.7013 - val_loss: 0.5498 - val_acc: 0.6160
# Epoch 48/250
#  - 0s - loss: 0.4954 - acc: 0.7040 - val_loss: 0.5470 - val_acc: 0.6160
# Epoch 49/250
#  - 0s - loss: 0.4922 - acc: 0.7147 - val_loss: 0.5444 - val_acc: 0.6160
# Epoch 50/250
#  - 0s - loss: 0.4891 - acc: 0.7133 - val_loss: 0.5416 - val_acc: 0.6160
# Epoch 51/250
#  - 0s - loss: 0.4859 - acc: 0.7200 - val_loss: 0.5390 - val_acc: 0.6240
# Epoch 52/250
#  - 0s - loss: 0.4829 - acc: 0.7213 - val_loss: 0.5365 - val_acc: 0.6280
# Epoch 53/250
#  - 0s - loss: 0.4799 - acc: 0.7240 - val_loss: 0.5339 - val_acc: 0.6320
# Epoch 54/250
#  - 0s - loss: 0.4770 - acc: 0.7240 - val_loss: 0.5315 - val_acc: 0.6320
# Epoch 55/250
#  - 0s - loss: 0.4741 - acc: 0.7267 - val_loss: 0.5290 - val_acc: 0.6360
# Epoch 56/250
#  - 0s - loss: 0.4713 - acc: 0.7280 - val_loss: 0.5266 - val_acc: 0.6400
# Epoch 57/250
#  - 0s - loss: 0.4686 - acc: 0.7320 - val_loss: 0.5243 - val_acc: 0.6480
# Epoch 58/250
#  - 0s - loss: 0.4658 - acc: 0.7360 - val_loss: 0.5220 - val_acc: 0.6480
# Epoch 59/250
#  - 0s - loss: 0.4631 - acc: 0.7387 - val_loss: 0.5197 - val_acc: 0.6520
# Epoch 60/250
#  - 0s - loss: 0.4604 - acc: 0.7413 - val_loss: 0.5174 - val_acc: 0.6560
# Epoch 61/250
#  - 0s - loss: 0.4578 - acc: 0.7440 - val_loss: 0.5151 - val_acc: 0.6600
# Epoch 62/250
#  - 0s - loss: 0.4552 - acc: 0.7467 - val_loss: 0.5129 - val_acc: 0.6600
# Epoch 63/250
#  - 0s - loss: 0.4527 - acc: 0.7480 - val_loss: 0.5107 - val_acc: 0.6640
# Epoch 64/250
#  - 0s - loss: 0.4502 - acc: 0.7507 - val_loss: 0.5086 - val_acc: 0.6640
# Epoch 65/250
#  - 0s - loss: 0.4476 - acc: 0.7507 - val_loss: 0.5064 - val_acc: 0.6640
# Epoch 66/250
#  - 0s - loss: 0.4452 - acc: 0.7520 - val_loss: 0.5043 - val_acc: 0.6680
# Epoch 67/250
#  - 0s - loss: 0.4427 - acc: 0.7533 - val_loss: 0.5022 - val_acc: 0.6720
# Epoch 68/250
#  - 0s - loss: 0.4403 - acc: 0.7547 - val_loss: 0.5001 - val_acc: 0.6720
# Epoch 69/250
#  - 0s - loss: 0.4379 - acc: 0.7560 - val_loss: 0.4980 - val_acc: 0.6720
# Epoch 70/250
#  - 0s - loss: 0.4355 - acc: 0.7587 - val_loss: 0.4961 - val_acc: 0.6760
# Epoch 71/250
#  - 0s - loss: 0.4332 - acc: 0.7640 - val_loss: 0.4942 - val_acc: 0.6760
# Epoch 72/250
#  - 0s - loss: 0.4310 - acc: 0.7653 - val_loss: 0.4922 - val_acc: 0.6840
# Epoch 73/250
#  - 0s - loss: 0.4288 - acc: 0.7680 - val_loss: 0.4903 - val_acc: 0.6880
# Epoch 74/250
#  - 0s - loss: 0.4266 - acc: 0.7693 - val_loss: 0.4883 - val_acc: 0.6880
# Epoch 75/250
#  - 0s - loss: 0.4244 - acc: 0.7707 - val_loss: 0.4864 - val_acc: 0.6920
# Epoch 76/250
#  - 0s - loss: 0.4222 - acc: 0.7707 - val_loss: 0.4845 - val_acc: 0.6960
# Epoch 77/250
#  - 0s - loss: 0.4202 - acc: 0.7707 - val_loss: 0.4827 - val_acc: 0.7040
# Epoch 78/250
#  - 0s - loss: 0.4181 - acc: 0.7707 - val_loss: 0.4808 - val_acc: 0.7120
# Epoch 79/250
#  - 0s - loss: 0.4161 - acc: 0.7733 - val_loss: 0.4790 - val_acc: 0.7160
# Epoch 80/250
#  - 0s - loss: 0.4140 - acc: 0.7760 - val_loss: 0.4772 - val_acc: 0.7200
# Epoch 81/250
#  - 0s - loss: 0.4120 - acc: 0.7773 - val_loss: 0.4754 - val_acc: 0.7200
# Epoch 82/250
#  - 0s - loss: 0.4100 - acc: 0.7800 - val_loss: 0.4737 - val_acc: 0.7200
# Epoch 83/250
#  - 0s - loss: 0.4081 - acc: 0.7800 - val_loss: 0.4719 - val_acc: 0.7240
# Epoch 84/250
#  - 0s - loss: 0.4062 - acc: 0.7813 - val_loss: 0.4702 - val_acc: 0.7240
# Epoch 85/250
#  - 0s - loss: 0.4043 - acc: 0.7813 - val_loss: 0.4686 - val_acc: 0.7240
# Epoch 86/250
#  - 0s - loss: 0.4025 - acc: 0.7813 - val_loss: 0.4670 - val_acc: 0.7280
# Epoch 87/250
#  - 0s - loss: 0.4007 - acc: 0.7840 - val_loss: 0.4653 - val_acc: 0.7280
# Epoch 88/250
#  - 0s - loss: 0.3988 - acc: 0.7840 - val_loss: 0.4636 - val_acc: 0.7280
# Epoch 89/250
#  - 0s - loss: 0.3970 - acc: 0.7867 - val_loss: 0.4620 - val_acc: 0.7280
# Epoch 90/250
#  - 0s - loss: 0.3953 - acc: 0.7867 - val_loss: 0.4604 - val_acc: 0.7280
# Epoch 91/250
#  - 0s - loss: 0.3936 - acc: 0.7920 - val_loss: 0.4588 - val_acc: 0.7280
# Epoch 92/250
#  - 0s - loss: 0.3919 - acc: 0.7947 - val_loss: 0.4573 - val_acc: 0.7360
# Epoch 93/250
#  - 0s - loss: 0.3901 - acc: 0.7973 - val_loss: 0.4556 - val_acc: 0.7440
# Epoch 94/250
#  - 0s - loss: 0.3885 - acc: 0.7987 - val_loss: 0.4542 - val_acc: 0.7480
# Epoch 95/250
#  - 0s - loss: 0.3869 - acc: 0.8013 - val_loss: 0.4527 - val_acc: 0.7520
# Epoch 96/250
#  - 0s - loss: 0.3852 - acc: 0.8040 - val_loss: 0.4511 - val_acc: 0.7520
# Epoch 97/250
#  - 0s - loss: 0.3836 - acc: 0.8067 - val_loss: 0.4497 - val_acc: 0.7520
# Epoch 98/250
#  - 0s - loss: 0.3821 - acc: 0.8067 - val_loss: 0.4482 - val_acc: 0.7520
# Epoch 99/250
#  - 0s - loss: 0.3805 - acc: 0.8107 - val_loss: 0.4467 - val_acc: 0.7520
# Epoch 100/250
#  - 0s - loss: 0.3790 - acc: 0.8120 - val_loss: 0.4453 - val_acc: 0.7520
# Epoch 101/250
#  - 0s - loss: 0.3774 - acc: 0.8120 - val_loss: 0.4438 - val_acc: 0.7560
# Epoch 102/250
#  - 0s - loss: 0.3758 - acc: 0.8147 - val_loss: 0.4424 - val_acc: 0.7560
# Epoch 103/250
#  - 0s - loss: 0.3743 - acc: 0.8133 - val_loss: 0.4411 - val_acc: 0.7560
# Epoch 104/250
#  - 0s - loss: 0.3729 - acc: 0.8133 - val_loss: 0.4397 - val_acc: 0.7560
# Epoch 105/250
#  - 0s - loss: 0.3714 - acc: 0.8147 - val_loss: 0.4384 - val_acc: 0.7560
# Epoch 106/250
#  - 0s - loss: 0.3701 - acc: 0.8147 - val_loss: 0.4372 - val_acc: 0.7560
# Epoch 107/250
#  - 0s - loss: 0.3687 - acc: 0.8173 - val_loss: 0.4358 - val_acc: 0.7560
# Epoch 108/250
#  - 0s - loss: 0.3673 - acc: 0.8173 - val_loss: 0.4345 - val_acc: 0.7560
# Epoch 109/250
#  - 0s - loss: 0.3659 - acc: 0.8187 - val_loss: 0.4333 - val_acc: 0.7560
# Epoch 110/250
#  - 0s - loss: 0.3646 - acc: 0.8187 - val_loss: 0.4320 - val_acc: 0.7560
# Epoch 111/250
#  - 0s - loss: 0.3632 - acc: 0.8187 - val_loss: 0.4307 - val_acc: 0.7560
# Epoch 112/250
#  - 0s - loss: 0.3619 - acc: 0.8187 - val_loss: 0.4295 - val_acc: 0.7560
# Epoch 113/250
#  - 0s - loss: 0.3607 - acc: 0.8200 - val_loss: 0.4282 - val_acc: 0.7560
# Epoch 114/250
#  - 0s - loss: 0.3594 - acc: 0.8213 - val_loss: 0.4270 - val_acc: 0.7560
# Epoch 115/250
#  - 0s - loss: 0.3581 - acc: 0.8213 - val_loss: 0.4257 - val_acc: 0.7560
# Epoch 116/250
#  - 0s - loss: 0.3570 - acc: 0.8240 - val_loss: 0.4247 - val_acc: 0.7560
# Epoch 117/250
#  - 0s - loss: 0.3559 - acc: 0.8253 - val_loss: 0.4236 - val_acc: 0.7560
# Epoch 118/250
#  - 0s - loss: 0.3547 - acc: 0.8280 - val_loss: 0.4226 - val_acc: 0.7560
# Epoch 119/250
#  - 0s - loss: 0.3536 - acc: 0.8307 - val_loss: 0.4215 - val_acc: 0.7600
# Epoch 120/250
#  - 0s - loss: 0.3525 - acc: 0.8307 - val_loss: 0.4205 - val_acc: 0.7600
# Epoch 121/250
#  - 0s - loss: 0.3514 - acc: 0.8307 - val_loss: 0.4195 - val_acc: 0.7600
# Epoch 122/250
#  - 0s - loss: 0.3503 - acc: 0.8307 - val_loss: 0.4184 - val_acc: 0.7600
# Epoch 123/250
#  - 0s - loss: 0.3492 - acc: 0.8320 - val_loss: 0.4174 - val_acc: 0.7640
# Epoch 124/250
#  - 0s - loss: 0.3482 - acc: 0.8347 - val_loss: 0.4164 - val_acc: 0.7640
# Epoch 125/250
#  - 0s - loss: 0.3471 - acc: 0.8347 - val_loss: 0.4152 - val_acc: 0.7680
# Epoch 126/250
#  - 0s - loss: 0.3460 - acc: 0.8360 - val_loss: 0.4142 - val_acc: 0.7680
# Epoch 127/250
#  - 0s - loss: 0.3450 - acc: 0.8373 - val_loss: 0.4132 - val_acc: 0.7680
# Epoch 128/250
#  - 0s - loss: 0.3439 - acc: 0.8413 - val_loss: 0.4123 - val_acc: 0.7680
# Epoch 129/250
#  - 0s - loss: 0.3429 - acc: 0.8413 - val_loss: 0.4113 - val_acc: 0.7680
# Epoch 130/250
#  - 0s - loss: 0.3420 - acc: 0.8427 - val_loss: 0.4104 - val_acc: 0.7680
# Epoch 131/250
#  - 0s - loss: 0.3410 - acc: 0.8427 - val_loss: 0.4095 - val_acc: 0.7720
# Epoch 132/250
#  - 0s - loss: 0.3401 - acc: 0.8427 - val_loss: 0.4085 - val_acc: 0.7720
# Epoch 133/250
#  - 0s - loss: 0.3391 - acc: 0.8440 - val_loss: 0.4076 - val_acc: 0.7760
# Epoch 134/250
#  - 0s - loss: 0.3383 - acc: 0.8480 - val_loss: 0.4067 - val_acc: 0.7760
# Epoch 135/250
#  - 0s - loss: 0.3374 - acc: 0.8480 - val_loss: 0.4059 - val_acc: 0.7760
# Epoch 136/250
#  - 0s - loss: 0.3365 - acc: 0.8493 - val_loss: 0.4050 - val_acc: 0.7760
# Epoch 137/250
#  - 0s - loss: 0.3357 - acc: 0.8507 - val_loss: 0.4042 - val_acc: 0.7800
# Epoch 138/250
#  - 0s - loss: 0.3349 - acc: 0.8507 - val_loss: 0.4035 - val_acc: 0.7800
# Epoch 139/250
#  - 0s - loss: 0.3341 - acc: 0.8507 - val_loss: 0.4027 - val_acc: 0.7800
# Epoch 140/250
#  - 0s - loss: 0.3333 - acc: 0.8520 - val_loss: 0.4018 - val_acc: 0.7840
# Epoch 141/250
#  - 0s - loss: 0.3325 - acc: 0.8533 - val_loss: 0.4011 - val_acc: 0.7840
# Epoch 142/250
#  - 0s - loss: 0.3317 - acc: 0.8520 - val_loss: 0.4003 - val_acc: 0.7840
# Epoch 143/250
#  - 0s - loss: 0.3310 - acc: 0.8533 - val_loss: 0.3996 - val_acc: 0.7840
# Epoch 144/250
#  - 0s - loss: 0.3303 - acc: 0.8533 - val_loss: 0.3989 - val_acc: 0.7840
# Epoch 145/250
#  - 0s - loss: 0.3296 - acc: 0.8547 - val_loss: 0.3982 - val_acc: 0.7880
# Epoch 146/250
#  - 0s - loss: 0.3289 - acc: 0.8587 - val_loss: 0.3974 - val_acc: 0.7880
# Epoch 147/250
#  - 0s - loss: 0.3281 - acc: 0.8600 - val_loss: 0.3967 - val_acc: 0.7880
# Epoch 148/250
#  - 0s - loss: 0.3274 - acc: 0.8613 - val_loss: 0.3960 - val_acc: 0.7880
# Epoch 149/250
#  - 0s - loss: 0.3267 - acc: 0.8613 - val_loss: 0.3953 - val_acc: 0.7880
# Epoch 150/250
#  - 0s - loss: 0.3260 - acc: 0.8613 - val_loss: 0.3947 - val_acc: 0.7880
# Epoch 151/250
#  - 0s - loss: 0.3254 - acc: 0.8613 - val_loss: 0.3941 - val_acc: 0.7880
# Epoch 152/250
#  - 0s - loss: 0.3248 - acc: 0.8627 - val_loss: 0.3934 - val_acc: 0.7880
# Epoch 153/250
#  - 0s - loss: 0.3242 - acc: 0.8640 - val_loss: 0.3927 - val_acc: 0.7880
# Epoch 154/250
#  - 0s - loss: 0.3235 - acc: 0.8640 - val_loss: 0.3921 - val_acc: 0.7880
# Epoch 155/250
#  - 0s - loss: 0.3229 - acc: 0.8653 - val_loss: 0.3915 - val_acc: 0.7920
# Epoch 156/250
#  - 0s - loss: 0.3223 - acc: 0.8653 - val_loss: 0.3909 - val_acc: 0.7920
# Epoch 157/250
#  - 0s - loss: 0.3217 - acc: 0.8667 - val_loss: 0.3904 - val_acc: 0.7920
# Epoch 158/250
#  - 0s - loss: 0.3212 - acc: 0.8680 - val_loss: 0.3898 - val_acc: 0.7920
# Epoch 159/250
#  - 0s - loss: 0.3206 - acc: 0.8693 - val_loss: 0.3893 - val_acc: 0.7920
# Epoch 160/250
#  - 0s - loss: 0.3201 - acc: 0.8667 - val_loss: 0.3887 - val_acc: 0.7960
# Epoch 161/250
#  - 0s - loss: 0.3196 - acc: 0.8680 - val_loss: 0.3882 - val_acc: 0.7960
# Epoch 162/250
#  - 0s - loss: 0.3190 - acc: 0.8693 - val_loss: 0.3877 - val_acc: 0.7960
# Epoch 163/250
#  - 0s - loss: 0.3185 - acc: 0.8680 - val_loss: 0.3871 - val_acc: 0.7960
# Epoch 164/250
#  - 0s - loss: 0.3180 - acc: 0.8680 - val_loss: 0.3866 - val_acc: 0.8000
# Epoch 165/250
#  - 0s - loss: 0.3175 - acc: 0.8680 - val_loss: 0.3861 - val_acc: 0.8000
# Epoch 166/250
#  - 0s - loss: 0.3171 - acc: 0.8680 - val_loss: 0.3856 - val_acc: 0.8000
# Epoch 167/250
#  - 0s - loss: 0.3167 - acc: 0.8693 - val_loss: 0.3852 - val_acc: 0.8000
# Epoch 168/250
#  - 0s - loss: 0.3163 - acc: 0.8693 - val_loss: 0.3848 - val_acc: 0.8000
# Epoch 169/250
#  - 0s - loss: 0.3159 - acc: 0.8693 - val_loss: 0.3844 - val_acc: 0.8000
# Epoch 170/250
#  - 0s - loss: 0.3154 - acc: 0.8680 - val_loss: 0.3839 - val_acc: 0.8000
# Epoch 171/250
#  - 0s - loss: 0.3150 - acc: 0.8680 - val_loss: 0.3835 - val_acc: 0.8040
# Epoch 172/250
#  - 0s - loss: 0.3147 - acc: 0.8680 - val_loss: 0.3832 - val_acc: 0.8040
# Epoch 173/250
#  - 0s - loss: 0.3143 - acc: 0.8667 - val_loss: 0.3828 - val_acc: 0.8040
# Epoch 174/250
#  - 0s - loss: 0.3140 - acc: 0.8667 - val_loss: 0.3824 - val_acc: 0.8040
# Epoch 175/250
#  - 0s - loss: 0.3135 - acc: 0.8667 - val_loss: 0.3819 - val_acc: 0.8040
# Epoch 176/250
#  - 0s - loss: 0.3132 - acc: 0.8667 - val_loss: 0.3815 - val_acc: 0.8040
# Epoch 177/250
#  - 0s - loss: 0.3128 - acc: 0.8667 - val_loss: 0.3811 - val_acc: 0.8040
# Epoch 178/250
#  - 0s - loss: 0.3124 - acc: 0.8667 - val_loss: 0.3807 - val_acc: 0.8040
# Epoch 179/250
#  - 0s - loss: 0.3121 - acc: 0.8667 - val_loss: 0.3804 - val_acc: 0.8080
# Epoch 180/250
#  - 0s - loss: 0.3118 - acc: 0.8680 - val_loss: 0.3800 - val_acc: 0.8080
# Epoch 181/250
#  - 0s - loss: 0.3115 - acc: 0.8680 - val_loss: 0.3797 - val_acc: 0.8080
# Epoch 182/250
#  - 0s - loss: 0.3112 - acc: 0.8680 - val_loss: 0.3794 - val_acc: 0.8080
# Epoch 183/250
#  - 0s - loss: 0.3109 - acc: 0.8680 - val_loss: 0.3791 - val_acc: 0.8080
# Epoch 184/250
#  - 0s - loss: 0.3106 - acc: 0.8680 - val_loss: 0.3788 - val_acc: 0.8120
# Epoch 185/250
#  - 0s - loss: 0.3103 - acc: 0.8680 - val_loss: 0.3784 - val_acc: 0.8160
# Epoch 186/250
#  - 0s - loss: 0.3101 - acc: 0.8680 - val_loss: 0.3781 - val_acc: 0.8160
# Epoch 187/250
#  - 0s - loss: 0.3098 - acc: 0.8680 - val_loss: 0.3778 - val_acc: 0.8160
# Epoch 188/250
#  - 0s - loss: 0.3095 - acc: 0.8693 - val_loss: 0.3776 - val_acc: 0.8160
# Epoch 189/250
#  - 0s - loss: 0.3092 - acc: 0.8707 - val_loss: 0.3773 - val_acc: 0.8160
# Epoch 190/250
#  - 0s - loss: 0.3090 - acc: 0.8707 - val_loss: 0.3770 - val_acc: 0.8160
# Epoch 191/250
#  - 0s - loss: 0.3088 - acc: 0.8693 - val_loss: 0.3767 - val_acc: 0.8160
# Epoch 192/250
#  - 0s - loss: 0.3085 - acc: 0.8707 - val_loss: 0.3765 - val_acc: 0.8160
# Epoch 193/250
#  - 0s - loss: 0.3083 - acc: 0.8707 - val_loss: 0.3762 - val_acc: 0.8160
# Epoch 194/250
#  - 0s - loss: 0.3080 - acc: 0.8707 - val_loss: 0.3760 - val_acc: 0.8160
# Epoch 195/250
#  - 0s - loss: 0.3078 - acc: 0.8707 - val_loss: 0.3758 - val_acc: 0.8200
# Epoch 196/250
#  - 0s - loss: 0.3076 - acc: 0.8707 - val_loss: 0.3755 - val_acc: 0.8200
# Epoch 197/250
#  - 0s - loss: 0.3074 - acc: 0.8707 - val_loss: 0.3753 - val_acc: 0.8200
# Epoch 198/250
#  - 0s - loss: 0.3072 - acc: 0.8707 - val_loss: 0.3750 - val_acc: 0.8200
# Epoch 199/250
#  - 0s - loss: 0.3070 - acc: 0.8707 - val_loss: 0.3748 - val_acc: 0.8200
# Epoch 200/250
#  - 0s - loss: 0.3067 - acc: 0.8707 - val_loss: 0.3745 - val_acc: 0.8200
# Epoch 201/250
#  - 0s - loss: 0.3065 - acc: 0.8707 - val_loss: 0.3743 - val_acc: 0.8200
# Epoch 202/250
#  - 0s - loss: 0.3063 - acc: 0.8720 - val_loss: 0.3741 - val_acc: 0.8200
# Epoch 203/250
#  - 0s - loss: 0.3061 - acc: 0.8707 - val_loss: 0.3738 - val_acc: 0.8200
# Epoch 204/250
#  - 0s - loss: 0.3060 - acc: 0.8720 - val_loss: 0.3736 - val_acc: 0.8200
# Epoch 205/250
#  - 0s - loss: 0.3058 - acc: 0.8720 - val_loss: 0.3734 - val_acc: 0.8200
# Epoch 206/250
#  - 0s - loss: 0.3056 - acc: 0.8720 - val_loss: 0.3732 - val_acc: 0.8200
# Epoch 207/250
#  - 0s - loss: 0.3054 - acc: 0.8707 - val_loss: 0.3730 - val_acc: 0.8200
# Epoch 208/250
#  - 0s - loss: 0.3053 - acc: 0.8707 - val_loss: 0.3728 - val_acc: 0.8200
# Epoch 209/250
#  - 0s - loss: 0.3051 - acc: 0.8720 - val_loss: 0.3726 - val_acc: 0.8200
# Epoch 210/250
#  - 0s - loss: 0.3049 - acc: 0.8720 - val_loss: 0.3724 - val_acc: 0.8200
# Epoch 211/250
#  - 0s - loss: 0.3048 - acc: 0.8707 - val_loss: 0.3722 - val_acc: 0.8200
# Epoch 212/250
#  - 0s - loss: 0.3047 - acc: 0.8720 - val_loss: 0.3721 - val_acc: 0.8200
# Epoch 213/250
#  - 0s - loss: 0.3045 - acc: 0.8720 - val_loss: 0.3719 - val_acc: 0.8200
# Epoch 214/250
#  - 0s - loss: 0.3044 - acc: 0.8720 - val_loss: 0.3717 - val_acc: 0.8200
# Epoch 215/250
#  - 0s - loss: 0.3042 - acc: 0.8707 - val_loss: 0.3716 - val_acc: 0.8200
# Epoch 216/250
#  - 0s - loss: 0.3041 - acc: 0.8707 - val_loss: 0.3714 - val_acc: 0.8200
# Epoch 217/250
#  - 0s - loss: 0.3040 - acc: 0.8707 - val_loss: 0.3713 - val_acc: 0.8200
# Epoch 218/250
#  - 0s - loss: 0.3038 - acc: 0.8707 - val_loss: 0.3712 - val_acc: 0.8200
# Epoch 219/250
#  - 0s - loss: 0.3037 - acc: 0.8720 - val_loss: 0.3710 - val_acc: 0.8200
# Epoch 220/250
#  - 0s - loss: 0.3036 - acc: 0.8733 - val_loss: 0.3709 - val_acc: 0.8200
# Epoch 221/250
#  - 0s - loss: 0.3035 - acc: 0.8733 - val_loss: 0.3707 - val_acc: 0.8200
# Epoch 222/250
#  - 0s - loss: 0.3034 - acc: 0.8733 - val_loss: 0.3706 - val_acc: 0.8200
# Epoch 223/250
#  - 0s - loss: 0.3033 - acc: 0.8720 - val_loss: 0.3705 - val_acc: 0.8240
# Epoch 224/250
#  - 0s - loss: 0.3032 - acc: 0.8720 - val_loss: 0.3704 - val_acc: 0.8240
# Epoch 225/250
#  - 0s - loss: 0.3031 - acc: 0.8720 - val_loss: 0.3702 - val_acc: 0.8240
# Epoch 226/250
#  - 0s - loss: 0.3030 - acc: 0.8720 - val_loss: 0.3701 - val_acc: 0.8280
# Epoch 227/250
#  - 0s - loss: 0.3029 - acc: 0.8720 - val_loss: 0.3700 - val_acc: 0.8280
# Epoch 228/250
#  - 0s - loss: 0.3028 - acc: 0.8720 - val_loss: 0.3699 - val_acc: 0.8280
# Epoch 229/250
#  - 0s - loss: 0.3028 - acc: 0.8733 - val_loss: 0.3698 - val_acc: 0.8280
# Epoch 230/250
#  - 0s - loss: 0.3027 - acc: 0.8733 - val_loss: 0.3697 - val_acc: 0.8280
# Epoch 231/250
#  - 0s - loss: 0.3026 - acc: 0.8733 - val_loss: 0.3696 - val_acc: 0.8280
# Epoch 232/250
#  - 0s - loss: 0.3025 - acc: 0.8733 - val_loss: 0.3695 - val_acc: 0.8280
# Epoch 233/250
#  - 0s - loss: 0.3024 - acc: 0.8733 - val_loss: 0.3694 - val_acc: 0.8280
# Epoch 234/250
#  - 0s - loss: 0.3023 - acc: 0.8733 - val_loss: 0.3693 - val_acc: 0.8280
# Epoch 235/250
#  - 0s - loss: 0.3022 - acc: 0.8720 - val_loss: 0.3692 - val_acc: 0.8280
# Epoch 236/250
#  - 0s - loss: 0.3021 - acc: 0.8720 - val_loss: 0.3691 - val_acc: 0.8280
# Epoch 237/250
#  - 0s - loss: 0.3021 - acc: 0.8720 - val_loss: 0.3690 - val_acc: 0.8280
# Epoch 238/250
#  - 0s - loss: 0.3020 - acc: 0.8720 - val_loss: 0.3689 - val_acc: 0.8280
# Epoch 239/250
#  - 0s - loss: 0.3019 - acc: 0.8720 - val_loss: 0.3688 - val_acc: 0.8280
# Epoch 240/250
#  - 0s - loss: 0.3019 - acc: 0.8720 - val_loss: 0.3686 - val_acc: 0.8280
# Epoch 241/250
#  - 0s - loss: 0.3018 - acc: 0.8720 - val_loss: 0.3685 - val_acc: 0.8280
# Epoch 242/250
#  - 0s - loss: 0.3017 - acc: 0.8720 - val_loss: 0.3684 - val_acc: 0.8280
# Epoch 243/250
#  - 0s - loss: 0.3017 - acc: 0.8720 - val_loss: 0.3684 - val_acc: 0.8280
# Epoch 244/250
#  - 0s - loss: 0.3016 - acc: 0.8707 - val_loss: 0.3683 - val_acc: 0.8280
# Epoch 245/250
#  - 0s - loss: 0.3016 - acc: 0.8707 - val_loss: 0.3682 - val_acc: 0.8280
# Epoch 246/250
#  - 0s - loss: 0.3015 - acc: 0.8707 - val_loss: 0.3681 - val_acc: 0.8280
# Epoch 247/250
#  - 0s - loss: 0.3015 - acc: 0.8707 - val_loss: 0.3680 - val_acc: 0.8280
# Epoch 248/250
#  - 0s - loss: 0.3014 - acc: 0.8693 - val_loss: 0.3680 - val_acc: 0.8280
# Epoch 249/250
#  - 0s - loss: 0.3014 - acc: 0.8693 - val_loss: 0.3679 - val_acc: 0.8280
# Epoch 250/250
#  - 0s - loss: 0.3013 - acc: 0.8693 - val_loss: 0.3678 - val_acc: 0.8280

# %% [markdown]
# #### 4.2 Auswertungen
# ##### 4.2.1 Zielfunktion und Genauigkeit im Verlauf der Epochen

# %%
# Kostenfunktion
plt.figure(figsize=(5,3))
plt.plot(model_history.epoch,
         model_history.history['loss'], 
         'b', 
         label = "Training")
plt.plot(model_history.epoch,
         model_history.history['val_loss'],
         'g',
         label = "Validation")
plt.legend(loc = 'upper right')
plt.title('Kostenfunktion');

# Genauigkeit
plt.figure(figsize=(5,3))
plt.plot(model_history.epoch,
         model_history.history['acc'],
        'b',
        label = "Training")
plt.plot(model_history.epoch,
         model_history.history['val_acc'],
        'g',
        label= "Validation")
plt.legend(loc = 'lower right')
plt.title('Genauigkeit');

# %% [markdown]
# ##### 4.2.2 Grafische Darstellung des Modells
#
# **Gesamter Datensatz**

# %%
plot_decision_boundary(lambda x: keras_model.predict_classes(x),X,y);

# %% [markdown]
# **Trainingsdaten**

# %%
plot_decision_boundary(lambda x: keras_model.predict_classes(x),X_train,y_train);

# %% [markdown]
# **Validierungsdaten**

# %%
plot_decision_boundary(lambda x: keras_model.predict_classes(x),X_test,y_test);

# %% [markdown]
# ##### 4.2.4 ROC curve

# %%
# calculate the fpr and tpr for all thresholds of the classification
# Training Data
probs_train = keras_model.predict_proba(X_train)
fpr_train, tpr_train, _ = roc_curve(y_train, probs_train[:,0])
auc_train = auc(fpr_train, tpr_train)

# Validation Data
probs_test = keras_model.predict_proba(X_test)
fpr_test, tpr_test, _ = roc_curve(y_test, probs_test[:,0])
auc_test = auc(fpr_test, tpr_test)

# %%
# Plot ROC curves + AUC values
plt.title('Receiver Operating Characteristic')
plt.plot(fpr_train, tpr_train, 'b', label = 'Train  (AUC = %0.4f)' % auc_train)
plt.plot(fpr_test,  tpr_test,  'g', label = 'Test   (AUC = %0.4f)' % auc_test)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# %% [markdown]
# ##### 4.2.5 Confusion Matrix
# **Trainingsdaten**

# %%
y_actu_train = pd.Series(y_train, name='Actual')
y_pred_train = pd.Series(keras_model.predict_classes(X_train)[:,0], name='Predicted')
df_conf_train = pd.crosstab(y_actu_train, y_pred_train)
print(df_conf_train)
# Out:
# Predicted    0    1
# Actual
# 0          328   48
# 1           50  324

# %% [markdown]
# **Validierungsdaten**

# %%
y_actu_test = pd.Series(y_test, name='Actual')
y_pred_test = pd.Series(keras_model.predict_classes(X_test)[:,0], name='Predicted')
df_conf_test = pd.crosstab(y_actu_test, y_pred_test)
print(df_conf_test)
# Out:
# Predicted    0    1
# Actual
# 0          105   19
# 1           24  102

# %% [markdown]
# ##### 4.2.6 Metriken

# %%
acc_train = accuracy_score(y_actu_train,y_pred_train)
acc_test  = accuracy_score(y_actu_test, y_pred_test)
print("-- Accuracy --")
print("Train:\t{:2.2f}%".format(acc_train*100))
print("Test:\t{:2.2f}%".format(acc_test*100))
print("\n-- Misclassification Rate --")
print("Train:\t{:2.2f}%".format((1-acc_train)*100))
print("Test:\t{:2.2f}%".format((1-acc_test)*100))
# Out:
# -- Accuracy --
# Train:	86.93%
# Test:	82.80%
#
# -- Misclassification Rate --
# Train:	13.07%
# Test:	17.20%

# %%
#CLOSE TF SESSION
K.clear_session()
