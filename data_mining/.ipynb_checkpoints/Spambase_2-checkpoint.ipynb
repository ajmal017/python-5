# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, AdaBoostClassifier
from  sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
import pandas as pd
import matplotlib.pyplot as plt
#import rpy2.robjects as ro
#from rpy2.robjects.packages import importr
#from rpy2.robjects import pandas2ri
#from rpy2.robjects.conversion import localconverter
from IPython.display import display

import warnings
warnings.simplefilter('ignore')

#pandas2ri.activate()

# %% [markdown]
# # Aufgabe 1

# %%
data = pd.read_csv("spambase.csv", sep=",").dropna()
print(len(data))
display(data.head(10))
# Out:
# 4456
#    Unnamed: 0  word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0           1            0.00               0.64           0.64           0.0
# 1           2            0.21               0.28           0.50           0.0
# 2           3            0.06               0.00           0.71           0.0
# 3           4            0.00               0.00           0.00           0.0
# 4           5            0.00               0.00           0.00           0.0
# 5           6            0.00               0.00           0.00           0.0
# 6           7            0.00               0.00           0.00           0.0
# 7           8            0.00               0.00           0.00           0.0
# 8           9            0.15               0.00           0.46           0.0
# 9          10            0.06               0.12           0.77           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
# 5           1.85            0.00              0.00                1.85
# 6           1.92            0.00              0.00                0.00
# 7           1.88            0.00              0.00                1.88
# 8           0.61            0.00              0.30                0.00
# 9           0.19            0.32              0.38                0.00
#
#    word_freq_order  ...  char_freq_semicolon  char_freq_round_bracket  \
# 0             0.00  ...                 0.00                    0.000
# 1             0.00  ...                 0.00                    0.132
# 2             0.64  ...                 0.01                    0.143
# 3             0.31  ...                 0.00                    0.137
# 4             0.31  ...                 0.00                    0.135
# 5             0.00  ...                 0.00                    0.223
# 6             0.00  ...                 0.00                    0.054
# 7             0.00  ...                 0.00                    0.206
# 8             0.92  ...                 0.00                    0.271
# 9             0.06  ...                 0.04                    0.030
#
#    char_freq_square_bracket  char_freq_exclamation_mark  char_freq_dollar  \
# 0                       0.0                       0.778             0.000
# 1                       0.0                       0.372             0.180
# 2                       0.0                       0.276             0.184
# 3                       0.0                       0.137             0.000
# 4                       0.0                       0.135             0.000
# 5                       0.0                       0.000             0.000
# 6                       0.0                       0.164             0.054
# 7                       0.0                       0.000             0.000
# 8                       0.0                       0.181             0.203
# 9                       0.0                       0.244             0.081
#
#    char_freq_hashtag  capital_run_length_average  capital_run_length_longest  \
# 0              0.000                       3.756                          61
# 1              0.048                       5.114                         101
# 2              0.010                       9.821                         485
# 3              0.000                       3.537                          40
# 4              0.000                       3.537                          40
# 5              0.000                       3.000                          15
# 6              0.000                       1.671                           4
# 7              0.000                       2.450                          11
# 8              0.022                       9.744                         445
# 9              0.000                       1.729                          43
#
#    capital_run_length_total  Target
# 0                       278       1
# 1                      1028       1
# 2                      2259       1
# 3                       191       1
# 4                       191       1
# 5                        54       1
# 6                       112       1
# 7                        49       1
# 8                      1257       1
# 9                       749       1
#
# [10 rows x 59 columns]

# %%
x = data.iloc[:,:-1].values
y = data['Target'].values

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.8, random_state=0)

# %%
def grid_search(model, x_train, y_train, x_test, y_test, params):
    print("UH Oh looks like you haven't payed the total amount. Please go to https://www.paypal.me/tobiKreiter and pay the requested amount.")

# %%
tuned_params = [{"n_estimators": range(100,200, 10)}]
grid_search(BaggingClassifier(DecisionTreeClassifier()), x_train, y_train, x_test, y_test, tuned_params)
grid_search(RandomForestClassifier(), x_train, y_train, x_test, y_test, tuned_params)
grid_search(AdaBoostClassifier(DecisionTreeClassifier()), x_train, y_train, x_test, y_test, tuned_params)
# Out:
# UH Oh looks like you haven't payed the total amount. Please go to https://www.paypal.me/tobiKreiter and pay the requested amount.
# UH Oh looks like you haven't payed the total amount. Please go to https://www.paypal.me/tobiKreiter and pay the requested amount.
# UH Oh looks like you haven't payed the total amount. Please go to https://www.paypal.me/tobiKreiter and pay the requested amount.
