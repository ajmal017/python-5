# %% [markdown]
# # SVM-Template
#
# *This Notebook gives an example on how to use SVM with `python` and `jupyter notebook`.
# Moreover it can be used as template for further ML tasks.*
#
# ## Preprocessing
#
# For having a generalized layout, the used data needs to always be stored within the `./data/` folder. Following code checks which data is present and can be used.

# %%
from subprocess import check_output
print(check_output(["ls", "./input"]).decode("utf8"))
# Out:
# gender_submission.csv
# test.csv
# train.csv

# %% [markdown]
# ## Import all libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

from sklearn.svm import SVC
from sklearn import metrics

import matplotlib.pyplot as plt
from helper import plot_classifier

# %matplotlib inline

# %% [markdown]
# ## Import the Data and inspect the Data

# %%
train = pd.read_csv('./input/train.csv')
test = pd.read_csv('./input/test.csv')
frames = [train, test]
dat = pd.concat(frames)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   after removing the cwd from sys.path.

# %%
dat.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket
# 0       3    male      1       0.0         A/5 21171
# 1       1  female      1       1.0          PC 17599
# 2       3  female      0       1.0  STON/O2. 3101282
# 3       1  female      1       1.0            113803
# 4       3    male      0       0.0            373450

# %%
corr = dat.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_d6abad42_98af_11e9_8edc_acde48001122row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d6abad42_98af_11e9_8edc_acde48001122row0_col1 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_d6abad42_98af_11e9_8edc_acde48001122row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d6abad42_98af_11e9_8edc_acde48001122row0_col3 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_d6abad42_98af_11e9_8edc_acde48001122row0_col4 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_d6abad42_98af_11e9_8edc_acde48001122row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d6abad42_98af_11e9_8edc_acde48001122row0_col6 {
#             background-color:  #799cf8;
#             color:  #000000;
# ...

# %% [markdown]
# Noe we search for zero values within the data.

# %%
dat.isnull().sum()
# Out:
# Age             263
# Cabin          1014
# Embarked          2
# Fare              1
# Name              0
# Parch             0
# PassengerId       0
# Pclass            0
# Sex               0
# SibSp             0
# Survived        418
# Ticket            0
# dtype: int64

# %%
dat.count()
# Out:
# Age            1046
# Cabin           295
# Embarked       1307
# Fare           1308
# Name           1309
# Parch          1309
# PassengerId    1309
# Pclass         1309
# Sex            1309
# SibSp          1309
# Survived        891
# Ticket         1309
# dtype: int64

# %%
dat = dat.dropna(subset = ['Survived'])

# %%
dat.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket
# 0       3    male      1       0.0         A/5 21171
# 1       1  female      1       1.0          PC 17599
# 2       3  female      0       1.0  STON/O2. 3101282
# 3       1  female      1       1.0            113803
# 4       3    male      0       0.0            373450

# %% [markdown]
# Now we have a dataframe which only contains values that can be classified. This means the `survived` column is not empty!
#
# Now we can start to process the data.

# %%
dat.count()
# Out:
# Age            714
# Cabin          204
# Embarked       889
# Fare           891
# Name           891
# Parch          891
# PassengerId    891
# Pclass         891
# Sex            891
# SibSp          891
# Survived       891
# Ticket         891
# dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
svc=SVC() #Default hyperparameters
svc.fit(X_train,y_train)
y_pred=svc.predict(X_test)
print('Accuracy Score:')
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-e46077c1d3c9> in <module>
#       1 svc=SVC() #Default hyperparameters
# ----> 2 svc.fit(X_train,y_train)
#       3 y_pred=svc.predict(X_test)
#       4 print('Accuracy Score:')
#       5 print(metrics.accuracy_score(y_test,y_pred))
#
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py in fit(self, X, y, sample_weight)
#     147         X, y = check_X_y(X, y, dtype=np.float64,
#     148                          order='C', accept_sparse='csr',
# --> 149                          accept_large_sparse=False)
#     150         y = self._validate_targets(y)
#     151
#
# ...
