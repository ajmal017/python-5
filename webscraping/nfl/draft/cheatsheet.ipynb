# %%
import pandas as pd

# %%
dfs = pd.read_excel('./csv/fantasy2020rankingsexcel.xlsx', sheet_name=['QBs', 'RBs', 'WRs', 'TEs', 'Ks'])

# %%
keeys = dfs.keys()

# %%
ddfs = []

for key in keeys:
    d = ddfs.append(dfs[key])

# %%
pd.concat(ddfs, axis=0)
# Out:
#      Last Name First Name       Team   Bye Pos  PASS YDS  PASS TD   INT  \
# 0      Mahomes    Patrick     Chiefs  10.0  QB    4700.0     42.0   6.0
# 1      Jackson      Lamar     Ravens   8.0  QB    3300.0     29.0   8.0
# 2       Wilson    Russell   Seahawks   6.0  QB    4100.0     32.0   6.0
# 3       Watson    Deshaun     Texans   8.0  QB    4000.0     25.0  12.0
# 4       Murray      Kyler  Cardinals   8.0  QB    4100.0     24.0  13.0
# ..         ...        ...        ...   ...  ..       ...      ...   ...
# 27     Sanders      Jason   Dolphins   NaN   K       NaN      NaN   NaN
# 28        Slye       Joey   Panthers   NaN   K       NaN      NaN   NaN
# 29     Pineiro       Eddy      Bears   NaN   K       NaN      NaN   NaN
# 30      Joseph       Greg     Titans   NaN   K       NaN      NaN   NaN
# 31  Rohrwasser     Justin   Patriots   NaN   K       NaN      NaN   NaN
#
#     RUSH YDS  CATCH  REC YDS  REG TD  Bonus  Dynst  Points (ESPN Scoring)  \
# ...
