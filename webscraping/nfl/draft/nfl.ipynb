# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://www.pro-football-reference.com/years/2019/fantasy.htm'
page = requests.get(url)

# %%
soup = BeautifulSoup(page.content, 'html.parser')

tbl = soup.find("table",{"id":"fantasy"})

players_2019 = pd.read_html(str(tbl))[0]

# %%
selRows = players_2019[players_2019['Unnamed: 0_level_0', 'Rk'] == 'Rk'].index
players_2019 = players_2019.drop(selRows, axis=0)

# %%
players_2019[27:35]
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                    Rk             Player                 Tm
# 27                 28     DeVante Parker                MIA
# 28                 29  Leonard Fournette                JAX
# 30                 30     Jameis Winston                TAM
# 31                 31     Austin Hooper*                ATL
# 32                 32      Amari Cooper*                DAL
# 33                 33        Mike Evans*                TAM
# 34                 34         A.J. Brown                TEN
# 35                 35  DeAndre Hopkins*+                HOU
#
#    Unnamed: 3_level_0 Unnamed: 4_level_0 Games     Passing                     \
#               FantPos                Age     G  GS     Cmp  Att   Yds  TD Int
# 27                 WR                 26    16  14       0    0     0   0   0
# 28                 RB                 24    15  15       0    0     0   0   0
# ...

# %%
players_2019.to_csv('players_2019')

# %% [markdown]
# # 2018

# %%
url = 'https://www.pro-football-reference.com/years/2018/fantasy.htm'
page = requests.get(url)

# %%
soup = BeautifulSoup(page.content, 'html.parser')

tbl = soup.find("table",{"id":"fantasy"})

players_2018 = pd.read_html(str(tbl))[0]

# %%
selRows = players_2018[players_2018['Unnamed: 0_level_0', 'Rk'] == 'Rk'].index
players_2018 = players_2018.drop(selRows, axis=0)

# %%
players_2018[27:35]
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                    Rk             Player                 Tm
# 27                 28        James White                NWE
# 28                 29   Phillip Lindsay*                DEN
# 30                 30      Derrick Henry                TEN
# 31                 31    Deshaun Watson*                HOU
# 32                 32      Tyler Lockett                SEA
# 33                 33       Stefon Diggs                MIN
# 34                 34      Brandin Cooks                LAR
# 35                 35      Keenan Allen*                LAC
#
#    Unnamed: 3_level_0 Unnamed: 4_level_0 Games     Passing                     \
#               FantPos                Age     G  GS     Cmp  Att   Yds  TD Int
# 27                 RB                 26    16   3       0    0     0   0   0
# 28                 RB                 24    15   8       0    0     0   0   0
# ...

# %%
players_2018.to_csv('players_2018')

# %% [markdown]
# # Defense
#
# ## 2019

# %%
url = 'https://www.pro-football-reference.com/years/2019/opp.htm'
page = requests.get(url)

# %%
soup = BeautifulSoup(page.content, 'html.parser')

tbl = soup.find("table",{"id":"team_stats"})

team_2019 = pd.read_html(str(tbl))[0]

# %%
team_2019[24:28]
# Out:
#    Unnamed: 0_level_0   Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                    Rk                   Tm                  G
# 24               25.0   Cincinnati Bengals               16.0
# 25               26.0        Detroit Lions               16.0
# 26               27.0  Washington Redskins               16.0
# 27               28.0    Arizona Cardinals               16.0
#
#    Unnamed: 3_level_0 Unnamed: 4_level_0 Tot Yds & TO             \
#                    PF                Yds          Ply  Y/P    TO
# 24              420.0             6299.0       1034.0  6.1  16.0
# 25              423.0             6406.0       1094.0  5.9  18.0
# 26              435.0             6162.0       1079.0  5.7  22.0
# 27              442.0             6432.0       1080.0  6.0  17.0
#
#    Unnamed: 8_level_0 Unnamed: 9_level_0 Passing                             \
#                    FL               1stD     Cmp    Att     Yds    TD   Int
# ...

# %%
team_2019.to_csv('team_defense_2019')

# %% [markdown]
# ## 2018

# %%
url = 'https://www.pro-football-reference.com/years/2018/opp.htm'
page = requests.get(url)

# %%
soup = BeautifulSoup(page.content, 'html.parser')

tbl = soup.find("table",{"id":"team_stats"})

team_2018 = pd.read_html(str(tbl))[0]

# %%
team_2018[24:28]
# Out:
#    Unnamed: 0_level_0   Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                    Rk                   Tm                  G
# 24               25.0      Atlanta Falcons               16.0
# 25               26.0    Arizona Cardinals               16.0
# 26               27.0       Miami Dolphins               16.0
# 27               28.0  San Francisco 49ers               16.0
#
#    Unnamed: 3_level_0 Unnamed: 4_level_0 Tot Yds & TO             \
#                    PF                Yds          Ply  Y/P    TO
# 24              423.0             6152.0       1031.0  6.0  19.0
# 25              425.0             5741.0       1065.0  5.4  16.0
# 26              433.0             6257.0       1024.0  6.1  28.0
# 27              435.0             5546.0       1023.0  5.4   7.0
#
#    Unnamed: 8_level_0 Unnamed: 9_level_0 Passing                             \
#                    FL               1stD     Cmp    Att     Yds    TD   Int
# ...

# %%
team_2018.to_csv('team_defense_2018')

# %% [markdown]
# # Offense
#
# ## 2019

# %%
url = 'https://www.pro-football-reference.com/years/2019/'
page = requests.get(url)

# %%
soup = BeautifulSoup(page.content, 'html.parser')

tbl = soup.find("table",{"id":"team_stats"})

off_2019 = pd.read_html(str(tbl))[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-121-4e1363638c3d> in <module>
#       3 tbl = soup.find("table",{"id":"team_stats"})
#       4
# ----> 5 off_2019 = pd.read_html(str(tbl))[0]
#
# /usr/local/anaconda3/envs/web/lib/python3.8/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1083         )
#    1084     validate_header_arg(header)
# -> 1085     return _parse(
#    1086         flavor=flavor,
#    1087         io=io,
#
# /usr/local/anaconda3/envs/web/lib/python3.8/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     913             break
#     914     else:
# --> 915         raise retained
#     916
#     917     ret = []
#
# ...

# %%
team_2018[24:28]
# Out:
#    Unnamed: 0_level_0   Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                    Rk                   Tm                  G
# 24               25.0      Atlanta Falcons               16.0
# 25               26.0    Arizona Cardinals               16.0
# 26               27.0       Miami Dolphins               16.0
# 27               28.0  San Francisco 49ers               16.0
#
#    Unnamed: 3_level_0 Unnamed: 4_level_0 Tot Yds & TO             \
#                    PF                Yds          Ply  Y/P    TO
# 24              423.0             6152.0       1031.0  6.0  19.0
# 25              425.0             5741.0       1065.0  5.4  16.0
# 26              433.0             6257.0       1024.0  6.1  28.0
# 27              435.0             5546.0       1023.0  5.4   7.0
#
#    Unnamed: 8_level_0 Unnamed: 9_level_0 Passing                             \
#                    FL               1stD     Cmp    Att     Yds    TD   Int
# ...

# %%
team_2018.to_csv('team_defense_2018')
