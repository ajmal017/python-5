# %% [markdown]
# # NFL Player

# %%
df = pd.read_csv('players_two_seasons.csv', index_col=[0])
df.head()
# Out:
#                       Tm FantPos  Age   G  GS  Cmp_p  Att_p  Yds_p  TD_p  \
# Christian McCaffrey  CAR      RB   23  32  32      1      3     50     1
# Lamar Jackson        BAL      QB   22  31  22    364    571   4328    42
# Derrick Henry        TEN      RB   25  31  27      2      3     14     0
# Aaron Jones          GNB      RB   25  28  24      0      0      0     0
# Ezekiel Elliott      DAL      RB   24  31  31      0      0      0     0
#
#                      Int_p  Att_r  Yds_r  Y/A_r  TD_r  Tgt_c  ...  Yds_c  \
# Christian McCaffrey      0    506   2485   9.84    22    266  ...   1872
# Lamar Jackson            9    323   1901  11.58    12      2  ...      0
# Derrick Henry            0    518   2599  10.01    28     42  ...    305
# Aaron Jones              0    369   1812  10.06    24    103  ...    680
# Ezekiel Elliott          0    605   2791   9.23    18    166  ...    987
#
#                      Y/R_c  TD_c  Fmb_f  FL_f  TD_f  2PM  2PP  FantPt    PPR  \
# ...

# %%
df.sort_values('PosRank', ascending=True)['FantPos'].head(10)
# Out:
# Travis Kelce           TE
# Christian McCaffrey    RB
# George Kittle          TE
# Patrick Mahomes        QB
# Zach Ertz              TE
# Deshaun Watson         QB
# Ezekiel Elliott        RB
# Michael Thomas         WR
# Julio Jones            WR
# Jared Cook             TE
# Name: FantPos, dtype: object

# %%
df[df['FantPos'] == 'RB'].sort_values('PosRank', ascending=True).head(10)
# Out:
#                       Tm FantPos  Age   G  GS  Cmp_p  Att_p  Yds_p  TD_p  \
# Christian McCaffrey  CAR      RB   23  32  32      1      3     50     1
# Ezekiel Elliott      DAL      RB   24  31  31      0      0      0     0
# Saquon Barkley       NYG      RB   22  29  29      0      0      0     0
# Todd Gurley          LAR      RB   25  29  29      0      0      0     0
# Derrick Henry        TEN      RB   25  31  27      2      3     14     0
# Joe Mixon            CIN      RB   23  30  28      0      0      0     0
# Alvin Kamara         NOR      RB   24  29  22      1      1     13     0
# Nick Chubb           CLE      RB   24  32  25      0      0      0     0
# Chris Carson         SEA      RB   25  29  29      0      0      0     0
# Aaron Jones          GNB      RB   25  28  24      0      0      0     0
#
#                      Int_p  Att_r  Yds_r  Y/A_r  TD_r  Tgt_c  ...  Yds_c  \
# Christian McCaffrey      0    506   2485   9.84    22    266  ...   1872
# ...

# %%
df[df['FantPos'] == 'QB'].sort_values('PosRank', ascending=True).head(10)
# Out:
#                   Tm FantPos  Age   G  GS  Cmp_p  Att_p  Yds_p  TD_p  Int_p  \
# Deshaun Watson   HOU      QB   24  31  31    678   1000   8017    52     21
# Patrick Mahomes  KAN      QB   24  30  30    702   1064   9128    76     17
# Dak Prescott     DAL      QB   26  32  32    744   1122   8787    52     19
# Russell Wilson   SEA      QB   31  32  32    621    943   7558    66     12
# Matt Ryan        ATL      QB   34  31  31    830   1224   9390    61     21
# Aaron Rodgers    GNB      QB   36  32  32    725   1166   8444    51      6
# Jared Goff       LAR      QB   25  32  32    758   1187   9326    54     28
# Tom Brady        NWE      QB   42  32  32    748   1183   8412    53     19
# Jameis Winston   TAM      QB   25  27  25    624   1004   8101    52     44
# Josh Allen       BUF      QB   23  28  27    440    781   5163    30     21
#
#                  Att_r  Yds_r  Y/A_r  TD_r  Tgt_c  ...  Yds_c  Y/R_c  TD_c  \
# ...

# %%
df[df['FantPos'] == 'WR'].sort_values('PosRank', ascending=True).head(10)
# Out:
#                   Tm FantPos  Age   G  GS  Cmp_p  Att_p  Yds_p  TD_p  Int_p  \
# Michael Thomas   NOR      WR   26  32  31      0      0      0     0      0
# Julio Jones      ATL      WR   30  31  31      0      0      0     0      0
# Mike Evans       TAM      WR   26  29  29      0      0      0     0      0
# DeAndre Hopkins  HOU      WR   27  31  31      1      3      6     1      1
# Kenny Golladay   DET      WR   26  31  29      0      0      0     0      0
# Keenan Allen     LAC      WR   27  32  30      0      0      0     0      0
# Tyler Lockett    SEA      WR   27  32  30      0      0      0     0      0
# Amari Cooper     DAL      WR   25  31  31      0      0      0     0      0
# Chris Godwin     TAM      WR   23  30  19      0      0      0     0      0
# Tyreek Hill      KAN      WR   25  28  28      0      0      0     0      0
#
#                  Att_r  Yds_r  Y/A_r  TD_r  Tgt_c  ...  Yds_c  Y/R_c  TD_c  \
# ...

# %% [markdown]
# # Plots
#
# **VBD: popularized by Joe Bryant in the 90s,this is the players fantasy points minus the fantasy points of the baseline player,where the baseline player is the 12th-ranked QB,the 24th-ranked RB,the 30th-ranked WR,or the 12th-ranked TE**
#
# ## RB

# %%
rb = df[df['FantPos'] == 'RB']

# %%
import plotly.express as px

df.columns
# Out:
# Index(['Tm', 'FantPos', 'Age', 'G', 'GS', 'Cmp_p', 'Att_p', 'Yds_p', 'TD_p',
#        'Int_p', 'Att_r', 'Yds_r', 'Y/A_r', 'TD_r', 'Tgt_c', 'Rec_c', 'Yds_c',
#        'Y/R_c', 'TD_c', 'Fmb_f', 'FL_f', 'TD_f', '2PM', '2PP', 'FantPt', 'PPR',
#        'DKPt', 'FDPt', 'VBD', 'PosRank', 'OvRank'],
#       dtype='object')

# %%
fig = px.scatter(rb, 'Att_r', 'Yds_r', hover_name=rb.index, color='TD_r')
fig.show()

# %%
rb_s = rb.sort_values('FantPt', ascending=False).head(20)

fig = px.bar(rb_s, x=rb_s.index, y='FantPt')
fig.show()

# %% [markdown]
# ## QB

# %%
qb = df[df['FantPos'] == 'QB']

# %%
qb.columns
# Out:
# Index(['Tm', 'FantPos', 'Age', 'G', 'GS', 'Cmp_p', 'Att_p', 'Yds_p', 'TD_p',
#        'Int_p', 'Att_r', 'Yds_r', 'Y/A_r', 'TD_r', 'Tgt_c', 'Rec_c', 'Yds_c',
#        'Y/R_c', 'TD_c', 'Fmb_f', 'FL_f', 'TD_f', '2PM', '2PP', 'FantPt', 'PPR',
#        'DKPt', 'FDPt', 'VBD', 'PosRank', 'OvRank'],
#       dtype='object')

# %%
fig = px.scatter(qb, 'Yds_p', 'Att_p', color='TD_p', hover_name=qb.index)
fig.show()

# %%
qb_s = qb.sort_values('FantPt', ascending=False).head(20)

fig = px.bar(qb_s, x=qb_s.index, y='FantPt')
fig.show()

# %% [markdown]
# ## WR

# %%
wr = df[df['FantPos'] == 'WR']

# %%
wr.columns
# Out:
# Index(['Tm', 'FantPos', 'Age', 'G', 'GS', 'Cmp_p', 'Att_p', 'Yds_p', 'TD_p',
#        'Int_p', 'Att_r', 'Yds_r', 'Y/A_r', 'TD_r', 'Tgt_c', 'Rec_c', 'Yds_c',
#        'Y/R_c', 'TD_c', 'Fmb_f', 'FL_f', 'TD_f', '2PM', '2PP', 'FantPt', 'PPR',
#        'DKPt', 'FDPt', 'VBD', 'PosRank', 'OvRank'],
#       dtype='object')

# %%
fig = px.scatter(wr, 'Y/R_c', 'Tgt_c', color='TD_c', hover_name=wr.index)
fig.show()

# %%
fig = px.scatter(wr, 'Yds_c', 'Tgt_c', color='TD_c', hover_name=wr.index)
fig.show()

# %%
wr_s = wr.sort_values('FantPt', ascending=False).head(20)

fig = px.bar(wr_s, x=wr_s.index, y='FantPt')
fig.show()

# %% [markdown]
# # Random

# %%
positions = ['WR', 'QB', 'RB']

# %%
def analysis(position):
    
    score1 = []
    score2 = []
    
    data = df[df['FantPos'] == position]
    
    print()
    print(position)
    
    score1 = data.sort_values('FantPt', ascending=False).index[:20]
    score2 = data.sort_values('VBD', ascending=False).index[:20]

    print(pd.DataFrame({'Fantasy':score1, 'VBD':score2}))
    
    print()
    print('#'*10)

# %%
for pos in positions:
    analysis(pos)
# Out:
# WR
#             Fantasy              VBD
# 0    Michael Thomas   Michael Thomas
# 1       Julio Jones      Julio Jones
# 2   DeAndre Hopkins  DeAndre Hopkins
# 3       Tyreek Hill      Tyreek Hill
# 4        Mike Evans       Mike Evans
# 5     Davante Adams    Davante Adams
# 6      Robert Woods     Robert Woods
# 7      Keenan Allen     Keenan Allen
# 8    Kenny Golladay   Kenny Golladay
# 9     Tyler Lockett    Tyler Lockett
# 10     Chris Godwin     Chris Godwin
# 11     Stefon Diggs     Stefon Diggs
# 12     Amari Cooper     Amari Cooper
# 13    Jarvis Landry    Jarvis Landry
# 14   Julian Edelman   Julian Edelman
# 15    Odell Beckham       Tyler Boyd
# 16     Adam Thielen    Calvin Ridley
# 17       Tyler Boyd      Cooper Kupp
# 18    Calvin Ridley   DeVante Parker
# 19      Cooper Kupp   Allen Robinson
#
# ##########
#
# QB
#               Fantasy               VBD
# 0     Patrick Mahomes   Patrick Mahomes
# 1      Deshaun Watson    Deshaun Watson
# ...

# %% [markdown]
# # Team

# %%
offense_2018.head(25)
# Out:
#                         Tm     G     PF     Yds     Ply  Y/P    TO    FL  \
# 1.0     Kansas City Chiefs  16.0  565.0  6810.0   996.0  6.8  18.0   6.0
# 2.0       Los Angeles Rams  16.0  527.0  6738.0  1060.0  6.4  19.0   7.0
# 12.0  Tampa Bay Buccaneers  16.0  396.0  6648.0  1055.0  6.3  35.0   9.0
# 8.0    Pittsburgh Steelers  16.0  428.0  6453.0  1058.0  6.1  26.0   9.0
# 4.0   New England Patriots  16.0  436.0  6295.0  1073.0  5.9  18.0   7.0
# ...                    ...   ...    ...     ...     ...  ...   ...   ...
# 9.0          Chicago Bears  16.0  421.0  5502.0  1013.0  5.4  24.0  10.0
# 22.0        Dallas Cowboys  16.0  339.0  5501.0  1022.0  5.4  17.0   9.0
# 28.0       Oakland Raiders  16.0  290.0  5379.0   995.0  5.4  24.0  14.0
# 25.0         Detroit Lions  16.0  324.0  5236.0  1019.0  5.1  19.0   7.0
# 27.0      Tennessee Titans  16.0  310.0  5002.0   940.0  5.3  18.0   6.0
#
#        1stD  Cmp_p  Att_p   Yds_p  TD_p  Int_p  NY/A_p  1stD_p  Att_r   Yds_r  \
# ...

# %%
offense_2018 = pd.read_csv('./2018_team_offense.csv', index_col=[0], header=[0,1], delimiter=';')
offense_2018.head(2)
# Out:
#      Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
# Rk                   Tm                  G                 PF
# 1.0  Kansas City Chiefs               16.0              565.0
# 2.0    Los Angeles Rams               16.0              527.0
#
#     Unnamed: 4_level_0 Tot Yds & TO            Unnamed: 8_level_0  \
# Rk                 Yds          Ply  Y/P    TO                 FL
# 1.0             6810.0        996.0  6.8  18.0                6.0
# 2.0             6738.0       1060.0  6.4  19.0                7.0
#
#     Unnamed: 9_level_0 Passing                                        Rushing  \
# Rk                1stD     Cmp    Att     Yds    TD   Int NY/A   1stD     Att
# 1.0              384.0   385.0  583.0  4955.0  50.0  12.0  8.1  239.0   387.0
# 2.0              401.0   368.0  568.0  4507.0  32.0  12.0  7.5  236.0   459.0
#
#                               Penalties               Unnamed: 25_level_0  \
# ...

# %%
offense_2018 = offense_2018.droplevel(0, axis=1)

# %%
offense_2018.columns = ['Tm', 'G', 'PF', 'Yds', 'Ply', 'Y/P', 'TO', 'FL', '1stD', 'Cmp_p', 'Att_p',
       'Yds_p', 'TD_p', 'Int_p', 'NY/A_p', '1stD_p', 'Att_r', 'Yds_r', 'TD_r', 'Y/A_r', '1stD_r',
       'penalties', 'Yds_penalties', '1st_penalties', 'Sc%', 'TO%', 'EXP']

# %%
offense_2018.head(3)
# Out:
#                      Tm     G     PF     Yds     Ply  Y/P    TO   FL   1stD  \
# 1.0  Kansas City Chiefs  16.0  565.0  6810.0   996.0  6.8  18.0  6.0  384.0
# 2.0    Los Angeles Rams  16.0  527.0  6738.0  1060.0  6.4  19.0  7.0  401.0
# 3.0  New Orleans Saints  16.0  504.0  6067.0  1010.0  6.0  16.0  9.0  377.0
#
#      Cmp_p  Att_p   Yds_p  TD_p  Int_p  NY/A_p  1stD_p  Att_r   Yds_r  TD_r  \
# 1.0  385.0  583.0  4955.0  50.0   12.0     8.1   239.0  387.0  1855.0  16.0
# 2.0  368.0  568.0  4507.0  32.0   12.0     7.5   236.0  459.0  2231.0  23.0
# 3.0  381.0  519.0  4042.0  33.0    7.0     7.5   210.0  471.0  2025.0  26.0
#
#      Y/A_r  1stD_r  penalties  Yds_penalties  1st_penalties   Sc%   TO%  \
# 1.0    4.8   108.0      137.0         1152.0           37.0  52.6  10.5
# 2.0    4.9   134.0       96.0          878.0           31.0  48.6   9.8
# 3.0    4.3   134.0       94.0          939.0           33.0  51.8   9.5
#
#         EXP
# 1.0  298.14
# 2.0  239.79
# 3.0  237.73

# %%
offense_2018 = offense_2018.head(-3)

# %%
offense_2019 = pd.read_csv('./2019_team_offense.csv', index_col=[0], header=[0,1], delimiter=';')
offense_2019.head(2)
# Out:
#       Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
# Rk                    Tm                  G                 PF
# 1.0     Baltimore Ravens               16.0              531.0
# 2.0  San Francisco 49ers               16.0              479.0
#
#     Unnamed: 4_level_0 Tot Yds & TO            Unnamed: 8_level_0  \
# Rk                 Yds          Ply  Y/P    TO                 FL
# 1.0             6521.0       1064.0  6.1  15.0                7.0
# 2.0             6097.0       1012.0  6.0  23.0               10.0
#
#     Unnamed: 9_level_0 Passing                                        Rushing  \
# Rk                1stD     Cmp    Att     Yds    TD   Int NY/A   1stD     Att
# 1.0              386.0   289.0  440.0  3225.0  37.0   8.0  6.9  171.0   596.0
# 2.0              336.0   331.0  478.0  3792.0  28.0  13.0  7.4  195.0   498.0
#
#                               Penalties              Unnamed: 25_level_0  \
# ...

# %%
offense_2019 = offense_2019.droplevel(0, axis=1)

# %%
offense_2019.columns = ['Tm', 'G', 'PF', 'Yds', 'Ply', 'Y/P', 'TO', 'FL', '1stD', 'Cmp_p', 'Att_p',
       'Yds_p', 'TD_p', 'Int_p', 'NY/A_p', '1stD_p', 'Att_r', 'Yds_r', 'TD_r', 'Y/A_r', '1stD_r',
       'penalties', 'Yds_penalties', '1st_penalties', 'Sc%', 'TO%', 'EXP']

# %%
offense_2019 = offense_2019.head(-3)

# %% [markdown]
# # Combine Seasons

# %%
offense_2018.columns
# Out:
# Index(['Tm', 'G', 'PF', 'Yds', 'Ply', 'Y/P', 'TO', 'FL', '1stD', 'Cmp_p',
#        'Att_p', 'Yds_p', 'TD_p', 'Int_p', 'NY/A_p', '1stD_p', 'Att_r', 'Yds_r',
#        'TD_r', 'Y/A_r', '1stD_r', 'penalties', 'Yds_penalties',
#        '1st_penalties', 'Sc%', 'TO%', 'EXP'],
#       dtype='object')

# %%
result = {}

for i in range(0, len(offense_2019)):
    t_2019 = offense_2019.iloc[i]['Tm']
    v_2019 = offense_2019.iloc[i][['G', 'PF', 'Yds', 'Ply', 'Y/P', 'TO', 'FL', '1stD', 'Cmp_p', 'Att_p',
       'Yds_p', 'TD_p', 'Int_p', 'NY/A_p', '1stD_p', 'Att_r', 'Yds_r', 'TD_r', 'Y/A_r', '1stD_r',
       'penalties', 'Yds_penalties', '1st_penalties', 'Sc%', 'TO%', 'EXP']]
    
    v_2018 = offense_2018[offense_2018['Tm'] == t_2019][['G', 'PF', 'Yds', 'Ply', 'Y/P', 'TO', 'FL', '1stD', 'Cmp_p', 'Att_p',
       'Yds_p', 'TD_p', 'Int_p', 'NY/A_p', '1stD_p', 'Att_r', 'Yds_r', 'TD_r', 'Y/A_r', '1stD_r',
       'penalties', 'Yds_penalties', '1st_penalties', 'Sc%', 'TO%', 'EXP']]
    
    resulting_df = (v_2019 + v_2018) / 2
    result[t_2019] = resulting_df

# %%
offense = pd.DataFrame()
for key, val in result.items():
    
    val['team'] = key
    offense = offense.append(val)

# %%
offense.set_index('team', inplace=True)

# %%
offense
# Out:
#                          G     PF     Yds     Ply   Y/P    TO    FL   1stD  \
# team
# Baltimore Ravens      16.0  460.0  6260.0  1099.5  5.70  17.5   9.0  376.5
# San Francisco 49ers   16.0  410.5  5933.0  1007.5  5.90  27.5  11.0  340.0
# Tampa Bay Buccaneers  16.0  427.0  6507.0  1070.5  6.10  38.0  10.0  370.5
# New Orleans Saints    16.0  481.0  6024.5  1010.5  5.95  12.0   5.5  362.0
# Kansas City Chiefs    16.0  508.0  6438.5   986.0  6.50  16.5   8.0  367.0
# ...                    ...    ...     ...     ...   ...   ...   ...    ...
# Denver Broncos        16.0  305.5  5189.5   984.5  5.25  18.5   6.0  299.5
# Chicago Bears         16.0  350.5  5125.5  1016.5  5.05  21.5   8.5  314.0
# Cincinnati Bengals    16.0  323.5  5070.5   993.5  5.10  23.5   9.0  308.0
# New York Jets         16.0  304.5  4577.5   963.5  4.75  27.5  10.0  255.5
# Washington Redskins   16.0  273.5  4595.0   926.0  5.00  20.0   6.0  264.0
#
# ...

# %% [markdown]
# ## Development

# %%
offense_2018
# Out:
#                         Tm     G     PF     Yds     Ply  Y/P    TO    FL  \
# 1.0     Kansas City Chiefs  16.0  565.0  6810.0   996.0  6.8  18.0   6.0
# 2.0       Los Angeles Rams  16.0  527.0  6738.0  1060.0  6.4  19.0   7.0
# 3.0     New Orleans Saints  16.0  504.0  6067.0  1010.0  6.0  16.0   9.0
# 4.0   New England Patriots  16.0  436.0  6295.0  1073.0  5.9  18.0   7.0
# 5.0     Indianapolis Colts  16.0  433.0  6179.0  1070.0  5.8  24.0   9.0
# ...                    ...   ...    ...     ...     ...  ...   ...   ...
# 28.0       Oakland Raiders  16.0  290.0  5379.0   995.0  5.4  24.0  14.0
# 29.0   Washington Redskins  16.0  281.0  4795.0   967.0  5.0  19.0   4.0
# 30.0         Buffalo Bills  16.0  269.0  4778.0  1008.0  4.7  32.0   9.0
# 31.0  Jacksonville Jaguars  16.0  245.0  4832.0  1005.0  4.8  29.0  16.0
# 32.0     Arizona Cardinals  16.0  225.0  3865.0   902.0  4.3  28.0  10.0
#
#        1stD  Cmp_p  Att_p   Yds_p  TD_p  Int_p  NY/A_p  1stD_p  Att_r   Yds_r  \
# ...

# %%
import plotly.graph_objects as go

print('2019')
print()

offense_2019 = offense_2019.sort_values('Yds', ascending=False)

teams=offense_2019['Tm']

fig = go.Figure(data=[
    go.Bar(name='Yards Rushing', x=teams, y=offense_2019['Yds_p']),
    go.Bar(name='Yards Passing', x=teams, y=offense_2019['Yds_r'])
])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show();

print('2018')
print()

offense_2018 = offense_2018.sort_values('Yds', ascending=False)

teams=offense_2018['Tm']

fig = go.Figure(data=[
    go.Bar(name='Yards Rushing', x=teams, y=offense_2018['Yds_p']),
    go.Bar(name='Yards Passing', x=teams, y=offense_2018['Yds_r'])
])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show();
# Out:
# 2019
# 2018

# %%
offense_2018[offense_2018['Tm'] == 'Kansas City Chiefs']
# Out:
# Index(['Tm', 'G', 'PF', 'Yds', 'Ply', 'Y/P', 'TO', 'FL', '1stD', 'Cmp_p',
#        'Att_p', 'Yds_p', 'TD_p', 'Int_p', 'NY/A_p', '1stD_p', 'Att_r', 'Yds_r',
#        'TD_r', 'Y/A_r', '1stD_r', 'penalties', 'Yds_penalties',
#        '1st_penalties', 'Sc%', 'TO%', 'EXP'],
#       dtype='object')

# %%
teams=offense_2018['Tm']
development = {}

for team in teams:
    
    stats_2018 = offense_2018[offense_2018['Tm'] == team][['PF', 'Yds', 'Ply', 'Y/P', 'TO', 'FL', '1stD', 'Cmp_p',
       'Att_p', 'Yds_p', 'TD_p', 'Int_p', 'NY/A_p', '1stD_p', 'Att_r', 'Yds_r',
       'TD_r', 'Y/A_r', '1stD_r', 'penalties', 'Yds_penalties',
       '1st_penalties', 'Sc%', 'TO%', 'EXP']]
    
    stats_2018.columns = ['PF_2018', 'Yds_2018', 'Ply_2018', 'Y/P_2018', 'TO_2018',
                                             'FL_2018', '1stD_2018', 'Cmp_p_2018', 'Att_p_2018', 'Yds_p_2018',
                                             'TD_p_2018', 'Int_p_2018', 'NY/A_p_2018', '1stD_r_2018',
                                             'Att_r_2018', 'Yds_r_2018', 'TD_r_2018', 'Y/A_r_2018',
                                             '1stD_r_2018', 'penalties_2018', 'Yds_penalties_2018',
                                             '1st_penalties_2018', 'Sc%_2018', 'TO%_2018', 'EXP_2018']

    

    stats_2019 = offense_2019[offense_2019['Tm'] == team][['PF', 'Yds', 'Ply', 'Y/P', 'TO', 'FL', '1stD', 'Cmp_p',
       'Att_p', 'Yds_p', 'TD_p', 'Int_p', 'NY/A_p', '1stD_r', 'Att_r', 'Yds_r',
       'TD_r', 'Y/A_r', '1stD_r', 'penalties', 'Yds_penalties',
       '1st_penalties', 'Sc%', 'TO%', 'EXP']]
    
    stats_2019.columns = ['PF_2019', 'Yds_2019', 'Ply_2019', 'Y/P_2019', 'TO_2019',
                                             'FL_2019', '1stD_2019', 'Cmp_p_2019', 'Att_p_2019', 'Yds_p_2019',
                                             'TD_p_2019', 'Int_p_2019', 'NY/A_p_2019', '1stD_r_2019',
                                             'Att_r_2019', 'Yds_r_2019', 'TD_r_2019', 'Y/A_r_2019',
                                             '1stD_r_2019', 'penalties_2019', 'Yds_penalties_2019',
                                             '1st_penalties_2019', 'Sc%_2019', 'TO%_2019', 'EXP_2019']
    
    s_18 = stats_2018.values[0]
    s_19 = stats_2019.values[0]
    
    development[team] = {
        'PF_2018':s_18[0], 'Yds_2018':s_18[1], 'Ply_2018':s_18[2], 'Y/P_2018':s_18[3], 'TO_2018':s_18[4],
        'FL_2018':s_18[5], '1stD_2018':s_18[6], 'Cmp_p_2018':s_18[7], 'Att_p_2018':s_18[8], 'Yds_p_2018':s_18[9],
        'TD_p_2018':s_18[10], 'Int_p_2018':s_18[11], 'NY/A_p_2018':s_18[12], '1stD_r_2018':s_18[13],
        'Att_r_2018':s_18[14], 'Yds_r_2018':s_18[15], 'TD_r_2018':s_18[16], 'Y/A_r_2018':s_18[17],
        '1stD_r_2018':s_18[18], 'penalties_2018':s_18[19], 'Yds_penalties_2018':s_18[20],
        '1st_penalties_2018':s_18[21], 'Sc%_2018':s_18[22], 'TO%_2018':s_18[23], 'EXP_2018':s_18[24],
        
        'PF_2019':s_19[0], 'Yds_2019':s_19[1], 'Ply_2019':s_19[2], 'Y/P_2019':s_19[3], 'TO_2019':s_19[4],
        'FL_2019':s_19[5], '1stD_2019':s_19[6], 'Cmp_p_2019':s_19[7], 'Att_p_2019':s_19[8], 'Yds_p_2019':s_19[9],
        'TD_p_2019':s_19[10], 'Int_p_2019':s_19[11], 'NY/A_p_2019':s_19[12], '1stD_r_2019':s_19[13],
        'Att_r_2019':s_19[14], 'Yds_r_2019':s_19[15], 'TD_r_2019':s_19[16], 'Y/A_r_2019':s_19[17],
        '1stD_r_2019':s_19[18], 'penalties_2019':s_19[19], 'Yds_penalties_2019':s_19[20],
        '1st_penalties_2019':s_19[21], 'Sc%_2019':s_19[22], 'TO%_2019':s_19[23], 'EXP_2019':s_19[24]
    }

# %%
development = pd.DataFrame(development).T

# %%
development.loc['Dallas Cowboys']['TD_r_2018']
# Out:
# 13.0

# %% [markdown]
# ## Offensive Yards

# %%
development.sort_values('Yds_2019',inplace=True, ascending=False)

teams = development.index

fig = go.Figure(data=[
    go.Bar(name='2019', x=teams, y=development['Yds_2019']),
    go.Bar(name='2018', x=teams, y=development['Yds_2018'])
])
# Change the bar mode
fig.update_layout(barmode='group')
fig.show();

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=teams, y=development['Yds_2019'], name='2019'))
fig.add_trace(go.Scatter(x=teams, y=development['Yds_2018'], fill='tonexty', name='2018')) # fill to trace0 y

fig.update_layout(title='YDS Comparison')
fig.show();

# %% [markdown]
# ## Points

# %%
development.sort_values('PF_2019',inplace=True, ascending=False)
teams = development.index

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=teams, y=development['PF_2019'], name='2019'))
fig.add_trace(go.Scatter(x=teams, y=development['PF_2018'], fill='tonexty', name='2018')) # fill to trace0 y

fig.update_layout(title='Score Points Comparison')
fig.show();

# %%
development.sort_values('EXP_2019',inplace=True, ascending=False)
teams = development.index

fig = go.Figure()
fig.add_trace(go.Scatter(x=teams, y=development['EXP_2019'], name='2019'))
fig.add_trace(go.Scatter(x=teams, y=development['EXP_2018'], fill='tonexty', name='2018')) # fill to trace0 y

fig.update_layout(title='Expexted Points Comparison')
fig.show();

# %% [markdown]
# ## Passing
#
# **NY/A: Net Yards gained per pass attempt.**
#
# $(Passing Yards - Sack Yards) / (Passes Attempted + Times Sacked)$
#
# **Minimum 14 attempts per schedule game to qualify as leader. Minimum 1500 pass attempts to qualify as career leader.**

# %%
development.sort_values('NY/A_p_2019',inplace=True, ascending=False)
teams = development.index

fig = go.Figure()
fig.add_trace(go.Scatter(x=teams, y=development['NY/A_p_2019'], name='2019'))
fig.add_trace(go.Scatter(x=teams, y=development['NY/A_p_2018'], fill='tonexty', name='2018')) # fill to trace0 y

fig.update_layout(title='Net Yards gained per Attempt')
fig.show();

# %%
development.sort_values('TD_p_2019',inplace=True, ascending=False)
teams = development.index

fig = go.Figure()
fig.add_trace(go.Scatter(x=teams, y=development['TD_p_2019'], name='2019'))
fig.add_trace(go.Scatter(x=teams, y=development['TD_p_2018'], fill='tonexty', name='2018')) # fill to trace0 y

fig.update_layout(title='Touchdowns')
fig.show();

# %% [markdown]
# ## Rushing

# %%
development.sort_values('TD_r_2019',inplace=True, ascending=False)
teams = development.index

fig = go.Figure()
fig.add_trace(go.Scatter(x=teams, y=development['TD_r_2019'], name='2019'))
fig.add_trace(go.Scatter(x=teams, y=development['TD_r_2018'], fill='tonexty', name='2018')) # fill to trace0 y

fig.update_layout(title='Touchdowns')
fig.show();

# %% [markdown]
# ## Turnover Kings

# %%
development.sort_values('TO%_2019',inplace=True, ascending=False)
teams = development.index

fig = go.Figure()
fig.add_trace(go.Scatter(x=teams, y=development['TO%_2019'], name='2019'))
fig.add_trace(go.Scatter(x=teams, y=development['TO%_2018'], fill='tonexty', name='2018')) # fill to trace0 y

fig.update_layout(title='Turnovers percentages')
fig.show();

# %% [markdown]
# ## Scatter

# %%
development.columns
# Out:
# Index(['PF_2018', 'Yds_2018', 'Ply_2018', 'Y/P_2018', 'TO_2018', 'FL_2018',
#        '1stD_2018', 'Cmp_p_2018', 'Att_p_2018', 'Yds_p_2018', 'TD_p_2018',
#        'Int_p_2018', 'NY/A_p_2018', '1stD_r_2018', 'Att_r_2018', 'Yds_r_2018',
#        'TD_r_2018', 'Y/A_r_2018', 'penalties_2018', 'Yds_penalties_2018',
#        '1st_penalties_2018', 'Sc%_2018', 'TO%_2018', 'EXP_2018', 'PF_2019',
#        'Yds_2019', 'Ply_2019', 'Y/P_2019', 'TO_2019', 'FL_2019', '1stD_2019',
#        'Cmp_p_2019', 'Att_p_2019', 'Yds_p_2019', 'TD_p_2019', 'Int_p_2019',
#        'NY/A_p_2019', '1stD_r_2019', 'Att_r_2019', 'Yds_r_2019', 'TD_r_2019',
#        'Y/A_r_2019', 'penalties_2019', 'Yds_penalties_2019',
#        '1st_penalties_2019', 'Sc%_2019', 'TO%_2019', 'EXP_2019'],
#       dtype='object')

# %%
fig = px.scatter(development, x = 'Yds_2018', y='Yds_2019', hover_name=development.index,
                color='PF_2019')
fig.show()
