# %%
import pandas as pd

# %%
positions =

# %%
player = pd.read_csv('players.csv', index_col=[0])
player
# Out:
#      Fantasy Points                 VBD               TD              YDS  \
# 0    Michael Thomas      Michael Thomas      Tyreek Hill   Michael Thomas
# 1       Julio Jones         Julio Jones   Michael Thomas      Julio Jones
# 2   DeAndre Hopkins     DeAndre Hopkins    Davante Adams  DeAndre Hopkins
# 3       Tyreek Hill         Tyreek Hill    Tyler Lockett       Mike Evans
# 4        Mike Evans          Mike Evans  DeAndre Hopkins     Keenan Allen
# ..              ...                 ...              ...              ...
# 35     LeSean McCoy        LeSean McCoy    Chase Edmonds  Jamaal Williams
# 36   Raheem Mostert         Gus Edwards   Brandon Bolden    Rashaad Penny
# 37  Kerryon Johnson  DeAndre Washington     Boston Scott     Ronald Jones
# 38      Gus Edwards         Tarik Cohen        Ito Smith  Damien Williams
# 39       Frank Gore         Matt Breida    Malcolm Brown       Dion Lewis
#
#       Attempts (Y/A) pos
# 0        Marvin Hall  WR
# 1         Chad Beebe  WR
# ...
