# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf
# For Notebooks
init_notebook_mode(connected=True)
# For offline use
cf.go_offline()
# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
import cufflinks as cf
import plotly.offline
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
plotly.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %% [markdown]
# # Graphical Analysis

# %%
tot_stats = pd.read_csv('./week4/total_offense')
tot_stats['YDS'] = tot_stats['YDS'].str.replace(",","").astype(float)
tot_stats.round(0)
# Out:
#                     Team  GP     YDS  YDS/G  YDS.1  YDS/G.1  YDS.2  YDS/G.2  \
# 0       Baltimore Ravens   4  1930.0  482.0  1,107    277.0    823    206.0
# 1     Kansas City Chiefs   4  1899.0  475.0  1,492    373.0    407    102.0
# 2         Dallas Cowboys   4  1701.0  425.0  1,119    280.0    582    146.0
# 3   Los Angeles Chargers   4  1615.0  404.0  1,201    300.0    414    104.0
# 4        New York Giants   4  1613.0  403.0  1,097    274.0    516    129.0
# ..                   ...  ..     ...    ...    ...      ...    ...      ...
# 27   Washington Redskins   4  1185.0  296.0    986    246.0    199     50.0
# 28   Pittsburgh Steelers   4  1134.0  284.0    876    219.0    258     64.0
# 29         Chicago Bears   4  1094.0  274.0    733    183.0    361     90.0
# 30        Miami Dolphins   4   900.0  225.0    693    173.0    207     52.0
# 31         New York Jets   3   590.0  197.0    393    131.0    197     66.0
#
#     PTS  PTS/G
# 0   135   34.0
# 1   135   34.0
# ...

# %%
tot_stats.head()
# Out:
#                    Team  GP     YDS  YDS/G  YDS.1  YDS/G.1  YDS.2  YDS/G.2  \
# 0      Baltimore Ravens   4  1930.0  482.5  1,107    276.8    823    205.8
# 1    Kansas City Chiefs   4  1899.0  474.8  1,492    373.0    407    101.8
# 2        Dallas Cowboys   4  1701.0  425.3  1,119    279.8    582    145.5
# 3  Los Angeles Chargers   4  1615.0  403.8  1,201    300.3    414    103.5
# 4       New York Giants   4  1613.0  403.3  1,097    274.3    516    129.0
#
#    PTS  PTS/G
# 0  135   33.8
# 1  135   33.8
# 2  107   26.8
# 3   90   22.5
# 4   87   21.8

# %% [markdown]
# After week 4 the five best teams when it comes to offensive yards are shown above.
# Let's import the specific team-stats.

# %%
baltimore = pd.read_csv('./results_by_team/BaltimoreRavens')
kansas = pd.read_csv('./results_by_team/KansasCityChiefs')
dallas = pd.read_csv('./results_by_team/DallasCowboys')
chargers = pd.read_csv('./results_by_team/LosAngelesChargers')
giants = pd.read_csv('./results_by_team/NewYorkGiants')

# %%
baltimore["YDS"] = baltimore["YDS"].str.replace(",","").astype(float)

# %%
baltimore.rename({'Unnamed: 0':'week'}, axis='columns', inplace=True)

# %%
baltimore.head()
# Out:
#     week   GP   CMP    ATT  CMP%     YDS   AVG  YDS/G   LNG    TD  INT  SACK  \
# 0  week1  1.0  23.0   26.0  88.5   378.0  14.6  378.0  83.0   6.0  0.0   1.0
# 1  week2  2.0  47.0   63.0  74.6   636.0  10.3  318.0  83.0   8.0  0.0   3.0
# 2  week3  3.0  69.0  106.0  65.1   885.0   8.7  295.0  83.0   8.0  0.0   6.0
# 3  week4  4.0  93.0  140.0  66.4  1107.0   8.3  276.8  83.0  11.0  2.0  10.0
#
#     SYL    RTG  ATT.1  YDS.1  AVG.1  YDS/G.1  LNG.1  TD.1  FUM  LST  \
# 0   1.0  158.3   46.0  265.0    5.8    265.0   60.0   2.0  0.0  0.0
# 1  15.0  146.9   79.0  447.0    5.7    223.5   60.0   2.0  0.0  0.0
# 2  33.0  117.6  111.0  650.0    5.9    216.7   60.0   6.0  0.0  0.0
# 3  58.0  112.3  140.0  823.0    5.9    205.8   60.0   6.0  2.0  1.0
#
#    BaltimoreRavens
# 0                1
# 1                1
# 2                0
# 3                0

# %%
a = tot_stats['YDS/G.2'].astype(int)
tot_stats.iplot(kind='scatter',x='Team',y='YDS/G.1',mode='markers', size=a / 10, showlegend=True)
# Out:
# <div>
#
#
#             <div id="e9150a03-f6ef-45a8-bf93-b9fad227531c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e9150a03-f6ef-45a8-bf93-b9fad227531c")) {
#                     Plotly.newPlot(
#                         'e9150a03-f6ef-45a8-bf93-b9fad227531c',
# ...

# %%
tot_stats[['YDS/G.1','YDS/G.2']].iplot(kind='spread')
# Out:
# <div>
#
#
#             <div id="6483ad76-27ef-48e4-a6dd-1cb4f50d744f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6483ad76-27ef-48e4-a6dd-1cb4f50d744f")) {
#                     Plotly.newPlot(
#                         '6483ad76-27ef-48e4-a6dd-1cb4f50d744f',
# ...
