# %% [markdown]
# # Analysis

# %%
import pandas as pd
import cufflinks as cf
import plotly.offline
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
import seaborn as sns
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
week1_tot_offense = pd.read_csv('./week1/total_offense')
week1_pass_offense = pd.read_csv('./week1/passing_offense')
week1_rec_offense = pd.read_csv('./week1/receiving_offense')
week1_rush_offense = pd.read_csv('./week1/rushing_offense')
week2_tot_offense = pd.read_csv('./week2/total_offense')
week2_pass_offense = pd.read_csv('./week2/passing_offense')
week2_rec_offense = pd.read_csv('./week2/receiving_offense')
week2_rush_offense = pd.read_csv('./week2/rushing_offense')
week3_tot_offense = pd.read_csv('./week3/total_offense')
week3_pass_offense = pd.read_csv('./week3/passing_offense')
week3_rec_offense = pd.read_csv('./week3/receiving_offense')
week3_rush_offense = pd.read_csv('./week3/rushing_offense')
week4_tot_offense = pd.read_csv('./week4/total_offense')
week4_pass_offense = pd.read_csv('./week4/passing_offense')
week4_rec_offense = pd.read_csv('./week4/receiving_offense')
week4_rush_offense = pd.read_csv('./week4/rushing_offense')

# %%
week1_pass_offense.head()
# Out:
#                   Team  GP  CMP  ATT  CMP%  YDS   AVG  YDS/G  LNG  TD  INT  \
# 0       Dallas Cowboys   1   25   32  78.1  405  12.7  405.0   62   4    0
# 1   Cincinnati Bengals   1   35   51  68.6  395   8.2  395.0   55   2    0
# 2   Kansas City Chiefs   1   25   34  73.5  378  11.1  378.0   68   3    0
# 3     Baltimore Ravens   1   23   26  88.5  378  14.6  378.0   83   6    0
# 4  Washington Redskins   1   30   44  68.2  370   8.6  370.0   69   3    0
#
#    SACK  SYL    RTG
# 0     0    0  158.3
# 1     5   23  106.5
# 2     0    0  139.1
# 3     1    1  158.3
# 4     1   10  117.6

# %%
week1_tot_offense.head()
# Out:
#                  Team  GP  YDS  YDS/G  YDS.1  YDS/G.1  YDS.2  YDS/G.2  PTS  \
# 0    Baltimore Ravens   1  643  643.0    378    378.0    265    265.0   59
# 1  New Orleans Saints   1  510  510.0    362    362.0    148    148.0   30
# 2      Dallas Cowboys   1  494  494.0    405    405.0     89     89.0   35
# 3  Kansas City Chiefs   1  491  491.0    378    378.0    113    113.0   40
# 4       Detroit Lions   1  477  477.0    361    361.0    116    116.0   27
#
#    PTS/G
# 0   59.0
# 1   30.0
# 2   35.0
# 3   40.0
# 4   27.0

# %%
top_pass = week1_pass_offense.head()
top_tot = week1_tot_offense.head()
bot_pass = week1_pass_offense.tail()
bot_tot = week1_tot_offense.tail()

# %%
top_pass['performance'] = 'top'
top_tot['performance'] = 'top'
bot_pass['performance'] = 'bottom'
bot_tot['performance'] = 'bottom'

# %%
pass_frames = [top_pass, bot_pass]
week1_pass = pd.concat(pass_frames)
week1_pass
# Out:
#                    Team  GP  CMP  ATT  CMP%  YDS   AVG  YDS/G  LNG  TD  INT  \
# 0        Dallas Cowboys   1   25   32  78.1  405  12.7  405.0   62   4    0
# 1    Cincinnati Bengals   1   35   51  68.6  395   8.2  395.0   55   2    0
# 2    Kansas City Chiefs   1   25   34  73.5  378  11.1  378.0   68   3    0
# 3      Baltimore Ravens   1   23   26  88.5  378  14.6  378.0   83   6    0
# 4   Washington Redskins   1   30   44  68.2  370   8.6  370.0   69   3    0
# 27    Green Bay Packers   1   18   30  60.0  166   6.8  166.0   47   1    0
# 28     Seattle Seahawks   1   14   20  70.0  161   9.8  161.0   44   2    0
# 29  San Francisco 49ers   1   18   27  66.7  158   6.1  158.0   39   1    1
# 30        New York Jets   1   28   41  68.3  155   4.3  155.0   19   1    0
# 31    Minnesota Vikings   1    8   10  80.0   97   9.8   97.0   31   1    0
#
#     SACK  SYL    RTG performance
# 0      0    0  158.3         top
# 1      5   23  106.5         top
# ...

# %%
tot_frames = [top_tot, bot_tot]
week1_tot = pd.concat(tot_frames)
week1_tot.head(10)
# Out:
#                   Team  GP  YDS  YDS/G  YDS.1  YDS/G.1  YDS.2  YDS/G.2  PTS  \
# 0     Baltimore Ravens   1  643  643.0    378    378.0    265    265.0   59
# 1   New Orleans Saints   1  510  510.0    362    362.0    148    148.0   30
# 2       Dallas Cowboys   1  494  494.0    405    405.0     89     89.0   35
# 3   Kansas City Chiefs   1  491  491.0    378    378.0    113    113.0   40
# 4        Detroit Lions   1  477  477.0    361    361.0    116    116.0   27
# 27       Chicago Bears   1  254  254.0    208    208.0     46     46.0    3
# 28    Seattle Seahawks   1  233  233.0    161    161.0     72     72.0   21
# 29       New York Jets   1  223  223.0    155    155.0     68     68.0   16
# 30   Green Bay Packers   1  213  213.0    166    166.0     47     47.0   10
# 31      Miami Dolphins   1  200  200.0    179    179.0     21     21.0   10
#
#     PTS/G performance
# 0    59.0         top
# 1    30.0         top
# 2    35.0         top
# 3    40.0         top
# ...

# %%
sns.jointplot(x='YDS',y='PTS',data=week1_tot_offense,kind='kde')

# %%
teamnames = list(week1_pass_offense['Team'])

# %%
teamnames
# Out:
# ['Dallas Cowboys',
#  'Cincinnati Bengals',
#  'Kansas City Chiefs',
#  'Baltimore Ravens',
#  'Washington Redskins',
#  'New England Patriots',
#  'New Orleans Saints',
#  'Detroit Lions',
#  'Jacksonville Jaguars',
#  'New York Giants',
#  'Philadelphia Eagles',
#  'Los Angeles Chargers',
#  'Pittsburgh Steelers',
#  'Arizona Cardinals',
#  'Atlanta Falcons',
#  'Oakland Raiders',
#  'Denver Broncos',
#  'Cleveland Browns',
#  'Buffalo Bills',
#  'Houston Texans',
#  'Tennessee Titans',
#  'Carolina Panthers',
#  'Chicago Bears',
#  'Los Angeles Rams',
#  'Miami Dolphins',
#  'Tampa Bay Buccaneers',
#  'Indianapolis Colts',
#  'Green Bay Packers',
#  'Seattle Seahawks',
#  'San Francisco 49ers',
#  'New York Jets',
#  'Minnesota Vikings']

# %%
team = pd.DataFrame(index=teamnames, columns=week1_tot_offense.columns)

# %%
def extract_team_stats(tot_offense):
    
    tot_offense_stats = []
    
    for name in teamnames:
        # print('-'*40)
        # print('This run will extract Informations for: ' + name)
        teamname = name
        teamname = pd.DataFrame(index=weeks, columns=week1_tot_offense.columns)
        teamname.drop('Team', axis=1)
        team_stats = tot_offense[tot_offense['Team']==name].values
        for i in range(1,2):
            teamname.iloc[i] = pd.Series({'GP':stats[0][0][1], 'YDS':stats[0][0][2], 'YDS/G':2, 'YDS.1':3, 'YDS/G.1':3, 'YDS.2':1, 'YDS/G.2':2, 'PTS':2, 'PTS/G':4})
        #tot_offense_stats.append(team_stats)
    
        # print('-'*40)
    return(teamname)

# %%
stats = extract_team_stats(week1_tot_offense)

# %%
stats
# Out:
#    Team   GP  YDS YDS/G YDS.1 YDS/G.1 YDS.2 YDS/G.2  PTS PTS/G
# 1   NaN  NaN  NaN   NaN   NaN     NaN   NaN     NaN  NaN   NaN
# 2   NaN    1  494     2     3       3     1       2    2     4
# 3   NaN  NaN  NaN   NaN   NaN     NaN   NaN     NaN  NaN   NaN
# 4   NaN  NaN  NaN   NaN   NaN     NaN   NaN     NaN  NaN   NaN
# 5   NaN  NaN  NaN   NaN   NaN     NaN   NaN     NaN  NaN   NaN
# 6   NaN  NaN  NaN   NaN   NaN     NaN   NaN     NaN  NaN   NaN
# 7   NaN  NaN  NaN   NaN   NaN     NaN   NaN     NaN  NaN   NaN
# 8   NaN  NaN  NaN   NaN   NaN     NaN   NaN     NaN  NaN   NaN
# 9   NaN  NaN  NaN   NaN   NaN     NaN   NaN     NaN  NaN   NaN
# 10  NaN  NaN  NaN   NaN   NaN     NaN   NaN     NaN  NaN   NaN
# 11  NaN  NaN  NaN   NaN   NaN     NaN   NaN     NaN  NaN   NaN
# 12  NaN  NaN  NaN   NaN   NaN     NaN   NaN     NaN  NaN   NaN
# 13  NaN  NaN  NaN   NaN   NaN     NaN   NaN     NaN  NaN   NaN
# 14  NaN  NaN  NaN   NaN   NaN     NaN   NaN     NaN  NaN   NaN
# ...

# %%
team_stats = week1_tot_offense[week1_tot_offense['Team']=='Baltimore Ravens'].values
team_stats
# Out:
# array([['Baltimore Ravens', 1, 643, 643.0, 378, 378.0, 265, 265.0, 59,
#         59.0]], dtype=object)

# %%
weeks = [i for i in range(1,17)]

# %%
team = pd.DataFrame(index=weeks, columns=week1_tot_offense.columns)

# %%
team.loc['Baltimore Ravens'] = pd.Series({'GP':stats[0][0][1], 'YDS':stats[0][0][2], 'YDS/G':2, 'YDS.1':3, 'YDS/G.1':3, 'YDS.2':1, 'YDS/G.2':2, 'PTS':2, 'PTS/G':4})

# %%
team = team.drop('Team', axis=1)
team
# Out:
#      GP  YDS YDS/G YDS.1 YDS/G.1 YDS.2 YDS/G.2  PTS PTS/G
# 1   NaN  NaN   NaN   NaN     NaN   NaN     NaN  NaN   NaN
# 2   NaN  NaN   NaN   NaN     NaN   NaN     NaN  NaN   NaN
# 3   NaN  NaN   NaN   NaN     NaN   NaN     NaN  NaN   NaN
# 4   NaN  NaN   NaN   NaN     NaN   NaN     NaN  NaN   NaN
# 5   NaN  NaN   NaN   NaN     NaN   NaN     NaN  NaN   NaN
# 6   NaN  NaN   NaN   NaN     NaN   NaN     NaN  NaN   NaN
# 7   NaN  NaN   NaN   NaN     NaN   NaN     NaN  NaN   NaN
# 8   NaN  NaN   NaN   NaN     NaN   NaN     NaN  NaN   NaN
# 9   NaN  NaN   NaN   NaN     NaN   NaN     NaN  NaN   NaN
# 10  NaN  NaN   NaN   NaN     NaN   NaN     NaN  NaN   NaN
# 11  NaN  NaN   NaN   NaN     NaN   NaN     NaN  NaN   NaN
# 12  NaN  NaN   NaN   NaN     NaN   NaN     NaN  NaN   NaN
# 13  NaN  NaN   NaN   NaN     NaN   NaN     NaN  NaN   NaN
# 14  NaN  NaN   NaN   NaN     NaN   NaN     NaN  NaN   NaN
# 15  NaN  NaN   NaN   NaN     NaN   NaN     NaN  NaN   NaN
# ...

# %%
stats[0][0][0]
# Out:
# 'Dallas Cowboys'
